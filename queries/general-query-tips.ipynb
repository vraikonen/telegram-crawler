# %% [markdown]
# # Tips for faster querying
#
# This notebook gives tips, shows examples on how to query MongoDB and, most importantly, examines different approaches based on their speed - all in pymongo, python driver for MongoDB.
#
# Furthemore, excluding APIs/drivers in other frameworks and languages, two most common ways to query MongoDB are:
#
#     - command line interface (mongosh - MongoDB shell) or
#     - GUI named MongoDB Compass (that has embedded MongoDB shell).
#
# Some operations are possible/easier to perform in Compass/shell, thus there is an occasional need for these as well. Moreover, choise depends on just a preference.
#
# This notebook is a reference to Telegram database with 30 million messages on 22.01.2024.
#
# As we are working with large files, you might need to update notebook RAM configuration, if you manage to mistakenly print large files. If needed, check this [blog post](https://towardsdatascience.com/leveraging-the-power-of-jupyter-notebooks-26b4b8d7c622).

# %% [markdown]
# # 0. Introduction
#
# Let's start by creating a client object, displaying databases, collections, and gathering information about them.
#
# In MongoDB, database has many collections, and each collection is represented by documents (BSONs i.e. binary JSONs).

# %%
# Function
import time


def get_speed(collection, query, projection):
    start_time = time.time()

    cursor = collection.find(query, projection)
    documents = list(cursor)

    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Number of documents retrieved: {len(documents)}")
    print(f"Time taken to list() retrieved documents: {elapsed_time} seconds")

    return documents

# %%
from pymongo import MongoClient
import re
import time
from pprint import pprint
from datetime import datetime
import sys

# Connect to MongoDB, path and namings of dbs and collections are the same as the ones defined in the config-database.ini before the crawl was initiated
client = MongoClient("mongodb://localhost:27017/")

# Let's check all the databases
dbs = client.list_database_names()
print("Databases:", dbs)
# Out:
# Databases: ['Telegram-090124-crawler', 'Telegram-1-crawler', 'Telegram-9-crawler', 'Test', 'admin', 'config', 'local', 'test-size', 'testing-size']

# %%
# Let's see our collections
db = client["Telegram-090124-crawler"]
collections = db.list_collection_names()

print("Collections:", collections)
# Out:
# Collections: ['messages', 'participants', 'chats', 'network']

# %%
collections_info = db.command("listCollections")
pprint(collections_info, indent=1)
# Out:
# {'cursor': {'firstBatch': [{'idIndex': {'key': {'_id': 1},
#                                         'name': '_id_',
#                                         'v': 2},
#                             'info': {'readOnly': False,
#                                      'uuid': UUID('5f31b076-3332-406c-9a0d-d282667b15a7')},
#                             'name': 'messages',
#                             'options': {},
#                             'type': 'collection'},
#                            {'idIndex': {'key': {'_id': 1},
#                                         'name': '_id_',
#                                         'v': 2},
#                             'info': {'readOnly': False,
#                                      'uuid': UUID('602eb318-401e-471a-aa76-79c7cf8adbfa')},
#                             'name': 'participants',
#                             'options': {},
#                             'type': 'collection'},
#                            {'idIndex': {'key': {'_id': 1},
#                                         'name': '_id_',
#                                         'v': 2},
#                             'info': {'readOnly': False,
#                                      'uuid': UUID('801c0ce8-e274-41f9-b065-499958d2f2bc')},
#                             'name': 'chats',
#                             'options': {},
#                             'type': 'collection'},
#                            {'idIndex': {'key': {'_id': 1},
#                                         'name': '_id_',
#                                         'v': 2},
#                             'info': {'readOnly': False,
#                                      'uuid': UUID('f6d94829-0a7c-4772-9c26-747465289a44')},
#                             'name': 'network',
#                             'options': {},
#                             'type': 'collection'}],
#             'id': 0,
#             'ns': 'Telegram-090124-crawler.$cmd.listCollections'},
#  'ok': 1.0}

# %%
# We can also acquire more info about collections
collection_details = db.command("collstats", "messages")
# print(collection_details)

print(f"Docuemnts count: {collection_details['count']}")
print(f"Collection size: {collection_details['size']}")
print(f"Average document size: {collection_details['avgObjSize']}")
print(f"Index size: {collection_details['totalIndexSize']}")
# Out:
# Docuemnts count: 29755431
# Collection size: 59586089993
# Average document size: 2002
# Index size: 1164312576

# %% [markdown]
# ## 0.1 Accessing documents - types of queries
#
# There are many ways we can query our MongoDB database and access documents.

# %% [markdown]
# ### Method collection_name.find_one()

# %%
# let's find one document from our collection messages, but first, let's initiate a variable for a connection
messages_collection = db["messages"]
one_document = messages_collection.find_one()

# We can check the structure of the document and assume uniformity with other documents
# Important: there are three types of message objects retrieved from telegram , check https://core.telegram.org/type/Message
pprint(one_document, indent=1)
# Out:
# {'_': 'Message',
#  '_id': ObjectId('659db99fcb4aa618cff2a132'),
#  'date': datetime.datetime(2023, 12, 15, 15, 11, 30),
#  'edit_date': None,
#  'edit_hide': False,
#  'entities': [{'_': 'MessageEntityUrl', 'length': 20, 'offset': 2}],
#  'forwards': None,
#  'from_id': {'_': 'PeerUser', 'user_id': 5963929426},
#  'from_scheduled': False,
#  'fwd_from': None,
#  'grouped_id': None,
#  'id': 16,
#  'legacy': False,
#  'media': {'_': 'MessageMediaWebPage',
#            'webpage': {'_': 'WebPage',
#                        'attributes': [],
#                        'author': None,
#                        'cached_page': None,
#                        'description': '"Communism was not created by the '
#                                       'masses to overthrow the bankers, '
#                                       'Communism was created by the bankers to '
#                                       'overthrow and enslave the masses."',
#                        'display_url': 't.me/thelastbattle20',
#                        'document': None,
#                        'duration': None,
#                        'embed_height': None,
#                        'embed_type': None,
#                        'embed_url': None,
#                        'embed_width': None,
#                        'hash': 0,
#                        'id': 9170793121369551478,
#                        'photo': {'_': 'Photo',
#                                  'access_hash': -3865197518031004110,
#                                  'date': datetime.datetime(2022, 1, 27, 23, 38, 45),
#                                  'dc_id': 4,
#                                  'file_reference': b'\x00e\x9d\xb9\x9f\xc32\x1f'
#                                                    b'EO\xe1\x8e\xb7E_\xda'
#                                                    b'\x91\\\x98S^',
#                                  'has_stickers': False,
#                                  'id': 6026229795559421675,
#                                  'sizes': [{'_': 'PhotoSize',
#                                             'h': 160,
#                                             'size': 15622,
#                                             'type': 'a',
#                                             'w': 160},
#                                            {'_': 'PhotoSize',
#                                             'h': 320,
#                                             'size': 48433,
#                                             'type': 'b',
#                                             'w': 320},
#                                            {'_': 'PhotoSize',
#                                             'h': 640,
#                                             'size': 129990,
#                                             'type': 'c',
#                                             'w': 640},
#                                            {'_': 'PhotoStrippedSize',
#                                             'bytes': b'\x01((\xbe\x03\x0c\xe0w'
#                                                      b'\xf4\xa8%\xbb'
#                                                      b'd\xce\x08\x00u\xc8\xa6_'
#                                                      b'\xdf\xc4\xb6\xf9'
#                                                      b'\x82P\\\x9cq\xda\xb1\xe4'
#                                                      b'\x9d\xe6q\xb9'
#                                                      b'\xb0*\xcc\x92'
#                                                      b'f\xf2\xbc\xae'
#                                                      b'\xb9*\x02\x91'
#                                                      b'\x90I\xc6\x7f\n\xa5<\xa1'
#                                                      b'ge\x03\xe6\x07\x15]]'
#                                                      b"\x84\x9b\xde\xeb\x80r8'"
#                                                      b'5ZWydiI\x00\x93\xcfj{'
#                                                      b'\x02\x8d\xcd$'
#                                                      b'\x95\xfc\xcc\xae'
#                                                      b'I\x1d\xf3Ef\x06e;'
#                                                      b'\x83r=\xe8\xa7t\x1c\x8c'
#                                                      b'`\xe0\x12G^\x95:\xc7'
#                                                      b'\x18@[%\xba\x9fA\xfe'
#                                                      b'5\x14h\x18d\xb0\x18\xf5'
#                                                      b'\xa9\x06\xed\xc5'
#                                                      b'w\x823\xc9?J\x9b\x96'
#                                                      b'\xc9\x1aB\xc4'
#                                                      b'\x15\xf3\x01\x18'
#                                                      b'\x1c\x8e)\x82!\x86%\x88'
#                                                      b'c\x9c\x01\xdf\xda\x97s|'
#                                                      b'\xa3\xcc\x19\xcf'
#                                                      b'\xa7J\x0e\xf6*<\xcc\x91'
#                                                      b'\xfd\xd1\x9aw'
#                                                      b'\xee\x16\xec@In\xa4\xe3'
#                                                      b'\xd34V\x9d\x95\x9aM1'
#                                                      b',\xfb[\xae\xd2:\x8fZ'
#                                                      b'(\xd1\n\xef\xa1RKW'
#                                                      b'\x89Y\xc6U@\xefP\xfc'
#                                                      b'\xe1\x15\xce0x\x14QC'
#                                                      b'A\x16\xc7 v\x07\x0c\xa3'
#                                                      b'i\x19\xcd:$\x9c\x9f\x91'
#                                                      b'C\x16\x07\xe5\xc7\\QE'
#                                                      b'&\xb4\x1d\xf544\xa8\xe7'
#                                                      b'k\x9f6D(\xaa\xa4d'
#                                                      b'\x8cf\x8a('
#                                                      b'\xa9\x06\xec\x7f',
#                                             'type': 'i'}],
#                                  'video_sizes': []},
#                        'site_name': 'Telegram',
#                        'title': 'EUROPA - THE LAST BATTLE V2 (plus bonus '
#                                 'content)',
#                        'type': 'telegram_channel',
#                        'url': 'https://t.me/thelastbattle20'}},
#  'media_unread': False,
#  'mentioned': False,
#  'message': '//t.me/thelastbattle20',
#  'noforwards': False,
#  'out': True,
#  'peer_id': {'_': 'PeerChannel', 'channel_id': 1318919825},
#  'pinned': False,
#  'post': False,
#  'post_author': None,
#  'reactions': None,
#  'replies': {'_': 'MessageReplies',
#              'channel_id': None,
#              'comments': False,
#              'max_id': None,
#              'read_max_id': None,
#              'recent_repliers': [],
#              'replies': 0,
#              'replies_pts': 18},
#  'reply_markup': None,
#  'reply_to': None,
#  'restriction_reason': [],
#  'silent': False,
#  'ttl_period': None,
#  'via_bot_id': None,
#  'views': None}

# %%
# Next, we can apply find_one based on a query, if there are more than one document that match our query, only one will be retrieved
# Input parameters for a query are {"key": "value"}

# let's find the date and time of the same message from the previous cell
print(one_document["date"])

target_date = datetime(2023, 12, 15, 15, 11, 30)
query = {"date": target_date}

one_specific_document = messages_collection.find_one(query)
pprint(one_specific_document, indent=1)
# Out:
# 2023-12-15 15:11:30
# {'_': 'Message',
#  '_id': ObjectId('659db99fcb4aa618cff2a132'),
#  'date': datetime.datetime(2023, 12, 15, 15, 11, 30),
#  'edit_date': None,
#  'edit_hide': False,
#  'entities': [{'_': 'MessageEntityUrl', 'length': 20, 'offset': 2}],
#  'forwards': None,
#  'from_id': {'_': 'PeerUser', 'user_id': 5963929426},
#  'from_scheduled': False,
#  'fwd_from': None,
#  'grouped_id': None,
#  'id': 16,
#  'legacy': False,
#  'media': {'_': 'MessageMediaWebPage',
#            'webpage': {'_': 'WebPage',
#                        'attributes': [],
#                        'author': None,
#                        'cached_page': None,
#                        'description': '"Communism was not created by the '
#                                       'masses to overthrow the bankers, '
#                                       'Communism was created by the bankers to '
#                                       'overthrow and enslave the masses."',
#                        'display_url': 't.me/thelastbattle20',
#                        'document': None,
#                        'duration': None,
#                        'embed_height': None,
#                        'embed_type': None,
#                        'embed_url': None,
#                        'embed_width': None,
#                        'hash': 0,
#                        'id': 9170793121369551478,
#                        'photo': {'_': 'Photo',
#                                  'access_hash': -3865197518031004110,
#                                  'date': datetime.datetime(2022, 1, 27, 23, 38, 45),
#                                  'dc_id': 4,
#                                  'file_reference': b'\x00e\x9d\xb9\x9f\xc32\x1f'
#                                                    b'EO\xe1\x8e\xb7E_\xda'
#                                                    b'\x91\\\x98S^',
#                                  'has_stickers': False,
#                                  'id': 6026229795559421675,
#                                  'sizes': [{'_': 'PhotoSize',
#                                             'h': 160,
#                                             'size': 15622,
#                                             'type': 'a',
#                                             'w': 160},
#                                            {'_': 'PhotoSize',
#                                             'h': 320,
#                                             'size': 48433,
#                                             'type': 'b',
#                                             'w': 320},
#                                            {'_': 'PhotoSize',
#                                             'h': 640,
#                                             'size': 129990,
#                                             'type': 'c',
#                                             'w': 640},
#                                            {'_': 'PhotoStrippedSize',
#                                             'bytes': b'\x01((\xbe\x03\x0c\xe0w'
#                                                      b'\xf4\xa8%\xbb'
#                                                      b'd\xce\x08\x00u\xc8\xa6_'
#                                                      b'\xdf\xc4\xb6\xf9'
#                                                      b'\x82P\\\x9cq\xda\xb1\xe4'
#                                                      b'\x9d\xe6q\xb9'
#                                                      b'\xb0*\xcc\x92'
#                                                      b'f\xf2\xbc\xae'
#                                                      b'\xb9*\x02\x91'
#                                                      b'\x90I\xc6\x7f\n\xa5<\xa1'
#                                                      b'ge\x03\xe6\x07\x15]]'
#                                                      b"\x84\x9b\xde\xeb\x80r8'"
#                                                      b'5ZWydiI\x00\x93\xcfj{'
#                                                      b'\x02\x8d\xcd$'
#                                                      b'\x95\xfc\xcc\xae'
#                                                      b'I\x1d\xf3Ef\x06e;'
#                                                      b'\x83r=\xe8\xa7t\x1c\x8c'
#                                                      b'`\xe0\x12G^\x95:\xc7'
#                                                      b'\x18@[%\xba\x9fA\xfe'
#                                                      b'5\x14h\x18d\xb0\x18\xf5'
#                                                      b'\xa9\x06\xed\xc5'
#                                                      b'w\x823\xc9?J\x9b\x96'
#                                                      b'\xc9\x1aB\xc4'
#                                                      b'\x15\xf3\x01\x18'
#                                                      b'\x1c\x8e)\x82!\x86%\x88'
#                                                      b'c\x9c\x01\xdf\xda\x97s|'
#                                                      b'\xa3\xcc\x19\xcf'
#                                                      b'\xa7J\x0e\xf6*<\xcc\x91'
#                                                      b'\xfd\xd1\x9aw'
#                                                      b'\xee\x16\xec@In\xa4\xe3'
#                                                      b'\xd34V\x9d\x95\x9aM1'
#                                                      b',\xfb[\xae\xd2:\x8fZ'
#                                                      b'(\xd1\n\xef\xa1RKW'
#                                                      b'\x89Y\xc6U@\xefP\xfc'
#                                                      b'\xe1\x15\xce0x\x14QC'
#                                                      b'A\x16\xc7 v\x07\x0c\xa3'
#                                                      b'i\x19\xcd:$\x9c\x9f\x91'
#                                                      b'C\x16\x07\xe5\xc7\\QE'
#                                                      b'&\xb4\x1d\xf544\xa8\xe7'
#                                                      b'k\x9f6D(\xaa\xa4d'
#                                                      b'\x8cf\x8a('
#                                                      b'\xa9\x06\xec\x7f',
#                                             'type': 'i'}],
#                                  'video_sizes': []},
#                        'site_name': 'Telegram',
#                        'title': 'EUROPA - THE LAST BATTLE V2 (plus bonus '
#                                 'content)',
#                        'type': 'telegram_channel',
#                        'url': 'https://t.me/thelastbattle20'}},
#  'media_unread': False,
#  'mentioned': False,
#  'message': '//t.me/thelastbattle20',
#  'noforwards': False,
#  'out': True,
#  'peer_id': {'_': 'PeerChannel', 'channel_id': 1318919825},
#  'pinned': False,
#  'post': False,
#  'post_author': None,
#  'reactions': None,
#  'replies': {'_': 'MessageReplies',
#              'channel_id': None,
#              'comments': False,
#              'max_id': None,
#              'read_max_id': None,
#              'recent_repliers': [],
#              'replies': 0,
#              'replies_pts': 18},
#  'reply_markup': None,
#  'reply_to': None,
#  'restriction_reason': [],
#  'silent': False,
#  'ttl_period': None,
#  'via_bot_id': None,
#  'views': None}

# %%
# Let's find another document that has 'edit_date' not None
# Note: as field "edit_date" does not have an index, it starts iterating over all messages
# until it finds one with "edit_date" not being None
# This should be done cautiously as if there is one field without the value you are looking for,
# it will iterate over every document in a collection

edit_date_document = messages_collection.find_one({"edit_date": {"$ne": None}})
pprint(edit_date_document, indent=1)
# Out:
# {'_': 'Message',
#  '_id': ObjectId('659db9a1cb4aa618cff2a14d'),
#  'date': datetime.datetime(2022, 5, 11, 20, 34, 46),
#  'edit_date': datetime.datetime(2022, 6, 4, 20, 52, 42),
#  'edit_hide': True,
#  'entities': [{'_': 'MessageEntityPre',
#                'language': '',
#                'length': 84,
#                'offset': 0},
#               {'_': 'MessageEntityBold', 'length': 7, 'offset': 84},
#               {'_': 'MessageEntityTextUrl',
#                'length': 8,
#                'offset': 92,
#                'url': 'https://www.discogs.com/it/master/789202-Musikkorps-Und-Soldatenchor-der-11-Panzer-Grenadier-Division-Leitung-Hauptmann-Hans-Frie%C3%9F-Wir-Singe'},
#               {'_': 'MessageEntityHashtag', 'length': 6, 'offset': 100},
#               {'_': 'MessageEntityHashtag', 'length': 8, 'offset': 107},
#               {'_': 'MessageEntityHashtag', 'length': 4, 'offset': 116},
#               {'_': 'MessageEntityTextUrl',
#                'length': 7,
#                'offset': 123,
#                'url': 'https://t.me/LoAgartha'}],
#  'forwards': 17,
#  'from_id': None,
#  'from_scheduled': False,
#  'fwd_from': None,
#  'grouped_id': None,
#  'id': 805,
#  'legacy': False,
#  'media': {'_': 'MessageMediaDocument',
#            'alt_document': None,
#            'document': {'_': 'Document',
#                         'access_hash': 6587621281042210858,
#                         'attributes': [{'_': 'DocumentAttributeAudio',
#                                         'duration': 141,
#                                         'performer': 'Musikkorps Der 11. '
#                                                      'Panzer Grenadier '
#                                                      'Division',
#                                         'title': 'Alte Kameraden (Major Hans '
#                                                  'Friess)',
#                                         'voice': False,
#                                         'waveform': None},
#                                        {'_': 'DocumentAttributeFilename',
#                                         'file_name': 'Alte Kameraden (Major '
#                                                      'Hans Friess).mp3'}],
#                         'date': datetime.datetime(2022, 5, 11, 20, 14, 9),
#                         'dc_id': 4,
#                         'file_reference': b'\x02B\xf34\xbe\x00\x00\x03'
#                                           b'%e\x9d\xb9\x9f\xceq\xdfb\xf45\xf9'
#                                           b'\xae\x06=\xa9\xb3\xaa\x10\n\xde',
#                         'id': 6043977145431100421,
#                         'mime_type': 'audio/mpeg',
#                         'size': 5668729,
#                         'thumbs': [],
#                         'video_thumbs': []},
#            'nopremium': False,
#            'spoiler': False,
#            'ttl_seconds': None},
#  'media_unread': False,
#  'mentioned': False,
#  'message': 'Musikkorps und Soldatenchor der 11. Panzergrenadierdivision - '
#             'Alte Kameraden, 1961\n'
#             '\n'
#             'Source: discogs\n'
#             '#music #germany #brd 〜 agartha',
#  'noforwards': False,
#  'out': False,
#  'peer_id': {'_': 'PeerChannel', 'channel_id': 1123235006},
#  'pinned': False,
#  'post': True,
#  'post_author': None,
#  'reactions': {'_': 'MessageReactions',
#                'can_see_list': False,
#                'min': False,
#                'recent_reactions': [],
#                'results': [{'_': 'ReactionCount',
#                             'chosen_order': None,
#                             'count': 13,
#                             'reaction': {'_': 'ReactionEmoji',
#                                          'emoticon': '❤'}},
#                            {'_': 'ReactionCount',
#                             'chosen_order': None,
#                             'count': 1,
#                             'reaction': {'_': 'ReactionEmoji',
#                                          'emoticon': '👍'}}]},
#  'replies': None,
#  'reply_markup': None,
#  'reply_to': None,
#  'restriction_reason': [],
#  'silent': False,
#  'ttl_period': None,
#  'via_bot_id': None,
#  'views': 6517}

# %% [markdown]
# ### Method collection_name.find()

# %%
# .find() applied on a collection returns a cursor that needs to be iterated over

# Note: if not parametrized, cursor represents all documents from the collection,
# so do not try to print or do anything else with millions of documents without setting a limit, or simply just iterate with indexing

# Let's skip first 100 documents, and access next 4
documents = messages_collection.find().skip(100).limit(4)

for document in documents:
    pprint(document, indent=1)

# Access just a subset of the documents
for index, document in enumerate(documents):
    if index < 2:
        print(document)
# Out:
# {'_': 'Message',
#  '_id': ObjectId('659db9a1cb4aa618cff2a19b'),
#  'date': datetime.datetime(2019, 12, 30, 0, 37, 54),
#  'edit_date': None,
#  'edit_hide': False,
#  'entities': [],
#  'forwards': 0,
#  'from_id': None,
#  'from_scheduled': False,
#  'fwd_from': None,
#  'grouped_id': None,
#  'id': 723,
#  'legacy': False,
#  'media': None,
#  'media_unread': False,
#  'mentioned': False,
#  'message': 'German version',
#  'noforwards': False,
#  'out': False,
#  'peer_id': {'_': 'PeerChannel', 'channel_id': 1123235006},
#  'pinned': False,
#  'post': True,
#  'post_author': None,
#  'reactions': None,
#  'replies': None,
#  'reply_markup': None,
#  'reply_to': {'_': 'MessageReplyHeader',
#               'forum_topic': False,
#               'reply_to_msg_id': 715,
#               'reply_to_peer_id': None,
#               'reply_to_scheduled': False,
#               'reply_to_top_id': None},
#  'restriction_reason': [],
#  'silent': False,
#  'ttl_period': None,
#  'via_bot_id': None,
#  'views': 1917}
# {'_': 'Message',
#  '_id': ObjectId('659db9a1cb4aa618cff2a19c'),
#  'date': datetime.datetime(2019, 12, 30, 0, 37, 46),
#  'edit_date': None,
#  'edit_hide': False,
#  'entities': [{'_': 'MessageEntityMention', 'length': 11, 'offset': 154}],
#  'forwards': 0,
#  'from_id': None,
#  'from_scheduled': False,
#  'fwd_from': None,
#  'grouped_id': None,
#  'id': 722,
#  'legacy': False,
#  'media': {'_': 'MessageMediaPhoto',
#            'photo': {'_': 'Photo',
#                      'access_hash': -3420824280334021234,
#                      'date': datetime.datetime(2019, 12, 30, 0, 20, 54),
#                      'dc_id': 4,
#                      'file_reference': b'\x02B\xf34\xbe\x00\x00\x02'
#                                        b'\xd2e\x9d\xb9\x9fb\xc3\xac'
#                                        b'(\x18\x18\xa5\\l\xb0\x87\x8f\x002\xd3'
#                                        b'\x0e',
#                      'has_stickers': False,
#                      'id': 5785306203545514400,
#                      'sizes': [{'_': 'PhotoStrippedSize',
#                                 'bytes': b'\x01!(\xd5\xcf=M\x19=\xc9\xa3\x9c'
#                                          b'\xf7\xfc\xa9zv\xcf\xe7@\x08\x0f<\x93'
#                                          b'R\x03\x91M\xc1\xf4\x1f\x9d\x00s\xd0~'
#                                          b't\x00\xea(\xa2\x80\x19\x96\xcfzO\x9b'
#                                          b'\xfd\xaaRG\xabR\xef\x1e\x86\x80\x13-'
#                                          b'\xfe\xd7\xf9\xfc(\x1b\x8fs'
#                                          b'\xfe\x7f\n]\xe3\xde\x8d\xe3'
#                                          b'\xde\x80\x14n\xefE\x01\x81'
#                                          b'\xa2\x80\nJ(\xa0\x00\xd1'
#                                          b'\xde\x8a(\x00\xefE\x14P\x07',
#                                 'type': 'i'},
#                                {'_': 'PhotoSize',
#                                 'h': 265,
#                                 'size': 24847,
#                                 'type': 'm',
#                                 'w': 320},
#                                {'_': 'PhotoSize',
#                                 'h': 370,
#                                 'size': 40491,
#                                 'type': 'x',
#                                 'w': 447}],
#                      'video_sizes': []},
#            'spoiler': False,
#            'ttl_seconds': None},
#  'media_unread': False,
#  'mentioned': False,
#  'message': '🇫🇷En Afrique, malgré le vent🇫🇷\n'
#             '\n'
#             "This is the french version of 'Auf Kreta im Sturm und im Regen'. "
#             'It was adopted by the Foreign Legion in the 1950s. \n'
#             '\n'
#             '@NsaMusic88',
#  'noforwards': False,
#  'out': False,
#  'peer_id': {'_': 'PeerChannel', 'channel_id': 1123235006},
#  'pinned': False,
#  'post': True,
#  'post_author': None,
#  'reactions': None,
#  'replies': None,
#  'reply_markup': None,
#  'reply_to': None,
#  'restriction_reason': [],
#  'silent': False,
#  'ttl_period': None,
#  'via_bot_id': None,
#  'views': 1917}
# {'_': 'Message',
#  '_id': ObjectId('659db9a1cb4aa618cff2a19d'),
#  'date': datetime.datetime(2019, 12, 25, 14, 47, 6),
#  'edit_date': None,
#  'edit_hide': False,
#  'entities': [{'_': 'MessageEntityUrl', 'length': 28, 'offset': 34},
#               {'_': 'MessageEntityMention', 'length': 11, 'offset': 64}],
#  'forwards': 10,
#  'from_id': None,
#  'from_scheduled': False,
#  'fwd_from': None,
#  'grouped_id': None,
#  'id': 721,
#  'legacy': False,
#  'media': {'_': 'MessageMediaDocument',
#            'alt_document': None,
#            'document': {'_': 'Document',
#                         'access_hash': -5948499496760299441,
#                         'attributes': [{'_': 'DocumentAttributeAudio',
#                                         'duration': 135,
#                                         'performer': 'Liang Zhu',
#                                         'title': 'Jingle Bells | 조선 '
#                                                  '종소리울려라【Songs and Marches '
#                                                  'from th',
#                                         'voice': False,
#                                         'waveform': None},
#                                        {'_': 'DocumentAttributeFilename',
#                                         'file_name': 'Jingle_Bells___조선_종소리울려라【Songs_and.mp3'}],
#                         'date': datetime.datetime(2019, 12, 25, 14, 42, 31),
#                         'dc_id': 4,
#                         'file_reference': b'\x02B\xf34\xbe\x00\x00\x02'
#                                           b'\xd1e\x9d\xb9\x9f\xaf\x93\xec'
#                                           b'$\xed\x04\xd0\x9d\x89R]'
#                                           b'\x83\x99\xe1A\xfb',
#                         'id': 5774029813698266876,
#                         'mime_type': 'audio/mpeg',
#                         'size': 2315681,
#                         'thumbs': [],
#                         'video_thumbs': []},
#            'nopremium': False,
#            'spoiler': False,
#            'ttl_seconds': None},
#  'media_unread': False,
#  'mentioned': False,
#  'message': '🇰🇵Jingle Bells | 조선 종소리울려라🇰🇵\n'
#             '\n'
#             'https://youtu.be/l4llEe2OPxo\n'
#             '\n'
#             '@NsaMusic88',
#  'noforwards': False,
#  'out': False,
#  'peer_id': {'_': 'PeerChannel', 'channel_id': 1123235006},
#  'pinned': False,
#  'post': True,
#  'post_author': None,
#  'reactions': None,
#  'replies': None,
#  'reply_markup': None,
#  'reply_to': None,
#  'restriction_reason': [],
#  'silent': False,
#  'ttl_period': None,
#  'via_bot_id': None,
#  'views': 2008}
# {'_': 'Message',
#  '_id': ObjectId('659db9a1cb4aa618cff2a19e'),
#  'date': datetime.datetime(2019, 12, 25, 14, 47, 5),
#  'edit_date': None,
#  'edit_hide': False,
#  'entities': [{'_': 'MessageEntityMention', 'length': 11, 'offset': 46}],
#  'forwards': 8,
#  'from_id': None,
#  'from_scheduled': False,
#  'fwd_from': None,
#  'grouped_id': None,
#  'id': 720,
#  'legacy': False,
#  'media': {'_': 'MessageMediaDocument',
#            'alt_document': None,
#            'document': {'_': 'Document',
#                         'access_hash': -3634285900405502203,
#                         'attributes': [{'_': 'DocumentAttributeAudio',
#                                         'duration': 179,
#                                         'performer': 'BingCrosbyLegacy',
#                                         'title': 'Bing Crosby - White '
#                                                  'Christmas (1942) Original '
#                                                  'Vers',
#                                         'voice': False,
#                                         'waveform': None},
#                                        {'_': 'DocumentAttributeFilename',
#                                         'file_name': 'Bing Crosby - White '
#                                                      'Christmas (1942) '
#                                                      'Original Vers.mp3'}],
#                         'date': datetime.datetime(2019, 12, 25, 14, 42, 22),
#                         'dc_id': 4,
#                         'file_reference': b'\x02B\xf34\xbe\x00\x00\x02'
#                                           b'\xd0e\x9d\xb9\x9f\xb6B\xd8:gs0'
#                                           b'\xc7\xfd&\x0f\xab\x91\xeaA)',
#                         'id': 5774029813698266875,
#                         'mime_type': 'audio/mpeg',
#                         'size': 2933802,
#                         'thumbs': [],
#                         'video_thumbs': []},
#            'nopremium': False,
#            'spoiler': False,
#            'ttl_seconds': None},
#  'media_unread': False,
#  'mentioned': False,
#  'message': '🇺🇸White Christmas (Bing Crosby - 1942)🇺🇸\n\n@NsaMusic88',
#  'noforwards': False,
#  'out': False,
#  'peer_id': {'_': 'PeerChannel', 'channel_id': 1123235006},
#  'pinned': False,
#  'post': True,
#  'post_author': None,
#  'reactions': None,
#  'replies': None,
#  'reply_markup': None,
#  'reply_to': None,
#  'restriction_reason': [],
#  'silent': False,
#  'ttl_period': None,
#  'via_bot_id': None,
#  'views': 1912}

# %%
# We can define a query to find messages that were forwarded
# Our query returns five messages that were forwarded to other chats
query = {"forwards": {"$nin": [None, 0]}}
forwarded_messages = messages_collection.find(query).limit(5)

# print(len(list(forwarded_messages)))
for message in forwarded_messages:
    pprint(message, indent=1)
# Out:
# {'_': 'Message',
#  '_id': ObjectId('659db99fcb4aa618cff2a13e'),
#  'date': datetime.datetime(2023, 7, 19, 8, 50, 35),
#  'edit_date': None,
#  'edit_hide': False,
#  'entities': [],
#  'forwards': 2,
#  'from_id': {'_': 'PeerUser', 'user_id': 5963929426},
#  'from_scheduled': False,
#  'fwd_from': {'_': 'MessageFwdHeader',
#               'channel_post': 2,
#               'date': datetime.datetime(2023, 7, 5, 11, 37, 56),
#               'from_id': {'_': 'PeerChannel', 'channel_id': 1976161109},
#               'from_name': None,
#               'imported': False,
#               'post_author': None,
#               'psa_type': None,
#               'saved_from_msg_id': None,
#               'saved_from_peer': None},
#  'grouped_id': None,
#  'id': 3,
#  'legacy': False,
#  'media': None,
#  'media_unread': False,
#  'mentioned': False,
#  'message': 'This is a test messages.',
#  'noforwards': False,
#  'out': True,
#  'peer_id': {'_': 'PeerChannel', 'channel_id': 1318919825},
#  'pinned': False,
#  'post': False,
#  'post_author': None,
#  'reactions': None,
#  'replies': {'_': 'MessageReplies',
#              'channel_id': None,
#              'comments': False,
#              'max_id': None,
#              'read_max_id': None,
#              'recent_repliers': [],
#              'replies': 0,
#              'replies_pts': 18},
#  'reply_markup': None,
#  'reply_to': None,
#  'restriction_reason': [],
#  'silent': False,
#  'ttl_period': None,
#  'via_bot_id': None,
#  'views': 7}
# {'_': 'Message',
#  '_id': ObjectId('659db99fcb4aa618cff2a13f'),
#  'date': datetime.datetime(2023, 7, 19, 8, 49, 47),
#  'edit_date': None,
#  'edit_hide': False,
#  'entities': [],
#  'forwards': 2,
#  'from_id': {'_': 'PeerUser', 'user_id': 5963929426},
#  'from_scheduled': False,
#  'fwd_from': {'_': 'MessageFwdHeader',
#               'channel_post': 2,
#               'date': datetime.datetime(2023, 7, 5, 11, 37, 56),
#               'from_id': {'_': 'PeerChannel', 'channel_id': 1976161109},
#               'from_name': None,
#               'imported': False,
#               'post_author': None,
#               'psa_type': None,
#               'saved_from_msg_id': None,
#               'saved_from_peer': None},
#  'grouped_id': None,
#  'id': 2,
#  'legacy': False,
#  'media': None,
#  'media_unread': False,
#  'mentioned': False,
#  'message': 'This is a test messages.',
#  'noforwards': False,
#  'out': True,
#  'peer_id': {'_': 'PeerChannel', 'channel_id': 1318919825},
#  'pinned': False,
#  'post': False,
#  'post_author': None,
#  'reactions': None,
#  'replies': {'_': 'MessageReplies',
#              'channel_id': None,
#              'comments': False,
#              'max_id': None,
#              'read_max_id': None,
#              'recent_repliers': [],
#              'replies': 0,
#              'replies_pts': 18},
#  'reply_markup': None,
#  'reply_to': None,
#  'restriction_reason': [],
#  'silent': False,
#  'ttl_period': None,
#  'via_bot_id': None,
#  'views': 7}
# {'_': 'Message',
#  '_id': ObjectId('659db9a1cb4aa618cff2a14d'),
#  'date': datetime.datetime(2022, 5, 11, 20, 34, 46),
#  'edit_date': datetime.datetime(2022, 6, 4, 20, 52, 42),
#  'edit_hide': True,
#  'entities': [{'_': 'MessageEntityPre',
#                'language': '',
#                'length': 84,
#                'offset': 0},
#               {'_': 'MessageEntityBold', 'length': 7, 'offset': 84},
#               {'_': 'MessageEntityTextUrl',
#                'length': 8,
#                'offset': 92,
#                'url': 'https://www.discogs.com/it/master/789202-Musikkorps-Und-Soldatenchor-der-11-Panzer-Grenadier-Division-Leitung-Hauptmann-Hans-Frie%C3%9F-Wir-Singe'},
#               {'_': 'MessageEntityHashtag', 'length': 6, 'offset': 100},
#               {'_': 'MessageEntityHashtag', 'length': 8, 'offset': 107},
#               {'_': 'MessageEntityHashtag', 'length': 4, 'offset': 116},
#               {'_': 'MessageEntityTextUrl',
#                'length': 7,
#                'offset': 123,
#                'url': 'https://t.me/LoAgartha'}],
#  'forwards': 17,
#  'from_id': None,
#  'from_scheduled': False,
#  'fwd_from': None,
#  'grouped_id': None,
#  'id': 805,
#  'legacy': False,
#  'media': {'_': 'MessageMediaDocument',
#            'alt_document': None,
#            'document': {'_': 'Document',
#                         'access_hash': 6587621281042210858,
#                         'attributes': [{'_': 'DocumentAttributeAudio',
#                                         'duration': 141,
#                                         'performer': 'Musikkorps Der 11. '
#                                                      'Panzer Grenadier '
#                                                      'Division',
#                                         'title': 'Alte Kameraden (Major Hans '
#                                                  'Friess)',
#                                         'voice': False,
#                                         'waveform': None},
#                                        {'_': 'DocumentAttributeFilename',
#                                         'file_name': 'Alte Kameraden (Major '
#                                                      'Hans Friess).mp3'}],
#                         'date': datetime.datetime(2022, 5, 11, 20, 14, 9),
#                         'dc_id': 4,
#                         'file_reference': b'\x02B\xf34\xbe\x00\x00\x03'
#                                           b'%e\x9d\xb9\x9f\xceq\xdfb\xf45\xf9'
#                                           b'\xae\x06=\xa9\xb3\xaa\x10\n\xde',
#                         'id': 6043977145431100421,
#                         'mime_type': 'audio/mpeg',
#                         'size': 5668729,
#                         'thumbs': [],
#                         'video_thumbs': []},
#            'nopremium': False,
#            'spoiler': False,
#            'ttl_seconds': None},
#  'media_unread': False,
#  'mentioned': False,
#  'message': 'Musikkorps und Soldatenchor der 11. Panzergrenadierdivision - '
#             'Alte Kameraden, 1961\n'
#             '\n'
#             'Source: discogs\n'
#             '#music #germany #brd 〜 agartha',
#  'noforwards': False,
#  'out': False,
#  'peer_id': {'_': 'PeerChannel', 'channel_id': 1123235006},
#  'pinned': False,
#  'post': True,
#  'post_author': None,
#  'reactions': {'_': 'MessageReactions',
#                'can_see_list': False,
#                'min': False,
#                'recent_reactions': [],
#                'results': [{'_': 'ReactionCount',
#                             'chosen_order': None,
#                             'count': 13,
#                             'reaction': {'_': 'ReactionEmoji',
#                                          'emoticon': '❤'}},
#                            {'_': 'ReactionCount',
#                             'chosen_order': None,
#                             'count': 1,
#                             'reaction': {'_': 'ReactionEmoji',
#                                          'emoticon': '👍'}}]},
#  'replies': None,
#  'reply_markup': None,
#  'reply_to': None,
#  'restriction_reason': [],
#  'silent': False,
#  'ttl_period': None,
#  'via_bot_id': None,
#  'views': 6517}
# {'_': 'Message',
#  '_id': ObjectId('659db9a1cb4aa618cff2a14e'),
#  'date': datetime.datetime(2022, 5, 11, 20, 34, 46),
#  'edit_date': datetime.datetime(2022, 7, 25, 2, 39, 51),
#  'edit_hide': True,
#  'entities': [{'_': 'MessageEntityCode', 'length': 82, 'offset': 0},
#               {'_': 'MessageEntityBold', 'length': 7, 'offset': 82},
#               {'_': 'MessageEntityTextUrl',
#                'length': 16,
#                'offset': 90,
#                'url': 'https://archive.org/details/ak_20211223'},
#               {'_': 'MessageEntityHashtag', 'length': 6, 'offset': 106},
#               {'_': 'MessageEntityHashtag', 'length': 8, 'offset': 113},
#               {'_': 'MessageEntityHashtag', 'length': 6, 'offset': 122},
#               {'_': 'MessageEntityTextUrl',
#                'length': 7,
#                'offset': 131,
#                'url': 'https://t.me/LoAgartha'}],
#  'forwards': 9,
#  'from_id': None,
#  'from_scheduled': False,
#  'fwd_from': None,
#  'grouped_id': None,
#  'id': 804,
#  'legacy': False,
#  'media': {'_': 'MessageMediaDocument',
#            'alt_document': None,
#            'document': {'_': 'Document',
#                         'access_hash': 3650520337669655870,
#                         'attributes': [{'_': 'DocumentAttributeAudio',
#                                         'duration': 262,
#                                         'performer': 'I. Musikkorps des '
#                                                      'Infanterie-Regiments '
#                                                      '"Groß-Deutschland"',
#                                         'title': 'Alte Kameraden (Friedrich '
#                                                  'Ahlers)',
#                                         'voice': False,
#                                         'waveform': None},
#                                        {'_': 'DocumentAttributeFilename',
#                                         'file_name': 'Alte Kameraden '
#                                                      '(instrumental).mp3'}],
#                         'date': datetime.datetime(2022, 5, 11, 20, 3, 41),
#                         'dc_id': 4,
#                         'file_reference': b'\x02B\xf34\xbe\x00\x00\x03'
#                                           b'$e\x9d\xb9\x9f6\xe7\xf2'
#                                           b'\x9dy\x7f\x1d\xd0\r\x85\xef'
#                                           b'b\xfc\x1a\xc4O',
#                         'id': 6043977145431100419,
#                         'mime_type': 'audio/mpeg',
#                         'size': 10503649,
#                         'thumbs': [],
#                         'video_thumbs': []},
#            'nopremium': False,
#            'spoiler': False,
#            'ttl_seconds': None},
#  'media_unread': False,
#  'mentioned': False,
#  'message': 'I. Musikkorps des Infanterie-Regiments "Groß-Deutschland" - Alte '
#             'Kameraden, 1936\n'
#             '\n'
#             'Source: InternetArchive\n'
#             '#music #germany #nsdap 〜 agartha',
#  'noforwards': False,
#  'out': False,
#  'peer_id': {'_': 'PeerChannel', 'channel_id': 1123235006},
#  'pinned': False,
#  'post': True,
#  'post_author': None,
#  'reactions': {'_': 'MessageReactions',
#                'can_see_list': False,
#                'min': False,
#                'recent_reactions': [],
#                'results': [{'_': 'ReactionCount',
#                             'chosen_order': None,
#                             'count': 9,
#                             'reaction': {'_': 'ReactionEmoji',
#                                          'emoticon': '❤'}},
#                            {'_': 'ReactionCount',
#                             'chosen_order': None,
#                             'count': 3,
#                             'reaction': {'_': 'ReactionEmoji',
#                                          'emoticon': '👍'}}]},
#  'replies': None,
#  'reply_markup': None,
#  'reply_to': None,
#  'restriction_reason': [],
#  'silent': False,
#  'ttl_period': None,
#  'via_bot_id': None,
#  'views': 6502}
# {'_': 'Message',
#  '_id': ObjectId('659db9a1cb4aa618cff2a14f'),
#  'date': datetime.datetime(2022, 5, 11, 20, 34, 46),
#  'edit_date': None,
#  'edit_hide': False,
#  'entities': [{'_': 'MessageEntityHashtag', 'length': 7, 'offset': 0},
#               {'_': 'MessageEntityTextUrl',
#                'length': 7,
#                'offset': 10,
#                'url': 'https://t.me/LoAgartha'}],
#  'forwards': 3,
#  'from_id': None,
#  'from_scheduled': False,
#  'fwd_from': None,
#  'grouped_id': None,
#  'id': 803,
#  'legacy': False,
#  'media': {'_': 'MessageMediaDocument',
#            'alt_document': None,
#            'document': {'_': 'Document',
#                         'access_hash': 3174932918104365619,
#                         'attributes': [{'_': 'DocumentAttributeImageSize',
#                                         'h': 553,
#                                         'w': 732},
#                                        {'_': 'DocumentAttributeFilename',
#                                         'file_name': '(lyrics) Alte '
#                                                      'Kameraden.png'}],
#                         'date': datetime.datetime(2022, 5, 11, 20, 1, 56),
#                         'dc_id': 4,
#                         'file_reference': b'\x02B\xf34\xbe\x00\x00\x03'
#                                           b'#e\x9d\xb9\x9f7[\xdf'
#                                           b'\xa8\x86\xc8\xde\x0cd\xc1D'
#                                           b'\x00\xd5\xcd5\xda',
#                         'id': 6043977145431100418,
#                         'mime_type': 'image/png',
#                         'size': 74059,
#                         'thumbs': [{'_': 'PhotoStrippedSize',
#                                     'bytes': b'\x01\x1e(\xd1\xe3\xdf\xf2\xa9'
#                                              b'c\x03\xae\xdcTy?\xdfjr\xb6\x0f'
#                                              b'R~\xb4\x00\xb2\xf6\xebM'
#                                              b'L\x16\xe8O\xe1N\x97\xb7$})\xa1'
#                                              b'\xb9\xfb\xcch\x02`1\xd2'
#                                              b'\x8a@\xd9\xf5\xfc\xa8\xa0\x08'
#                                              b'\x7f\xe0B\xa5U\xe0g\x07'
#                                              b'\xf0\xa8\xce}\x17\xf2\xa9S'
#                                              b'\xee\xd0\x03%\xed\xce)\x14'
#                                              b'd\xf0\xdf\xa5:L\xe4c'
#                                              b'\x1f\x8d\x08\t\xcfo\xa5\x00'
#                                              b'<t\xa2\x8a(\x03',
#                                     'type': 'i'},
#                                    {'_': 'PhotoSize',
#                                     'h': 242,
#                                     'size': 25252,
#                                     'type': 'm',
#                                     'w': 320}],
#                         'video_thumbs': []},
#            'nopremium': False,
#            'spoiler': False,
#            'ttl_seconds': None},
#  'media_unread': False,
#  'mentioned': False,
#  'message': '#lyrics 〜 agartha',
#  'noforwards': False,
#  'out': False,
#  'peer_id': {'_': 'PeerChannel', 'channel_id': 1123235006},
#  'pinned': False,
#  'post': True,
#  'post_author': None,
#  'reactions': None,
#  'replies': None,
#  'reply_markup': None,
#  'reply_to': None,
#  'restriction_reason': [],
#  'silent': False,
#  'ttl_period': None,
#  'via_bot_id': None,
#  'views': 6340}

# %%
# We can also retrieve only fields that we need by defining "projection",
# Projection is a second arguemnt it defines what fields we want to retrieve

# Let's first filter messages that were forwarded to other chats,
# but let's only retrieve message text, id of the user that send it to current chat, and id of channel that it came from, if it came from somewhere
cursor = messages_collection.find(
    {"forwards": {"$nin": [None, 0]}},
    {
        "message": 1,
        "forwards": 1,
        "fwd_from.from_id.channel_id": 1,
        "from_id.user_id": 1,
    },
).limit(10)

for document in cursor:
    pprint(document, indent=2)

# To wrap up: we filtered only 10 messages that were forwarded to other chats, but from a whole message, we recieved
# fields that says from which channel the message was forwarded to the current channel as well as
# Out:
# { '_id': ObjectId('659db99fcb4aa618cff2a13e'),
#   'forwards': 2,
#   'from_id': {'user_id': 5963929426},
#   'fwd_from': {'from_id': {'channel_id': 1976161109}},
#   'message': 'This is a test messages.'}
# { '_id': ObjectId('659db99fcb4aa618cff2a13f'),
#   'forwards': 2,
#   'from_id': {'user_id': 5963929426},
#   'fwd_from': {'from_id': {'channel_id': 1976161109}},
#   'message': 'This is a test messages.'}
# { '_id': ObjectId('659db9a1cb4aa618cff2a14d'),
#   'forwards': 17,
#   'message': 'Musikkorps und Soldatenchor der 11. Panzergrenadierdivision - '
#              'Alte Kameraden, 1961\n'
#              '\n'
#              'Source: discogs\n'
#              '#music #germany #brd 〜 agartha'}
# { '_id': ObjectId('659db9a1cb4aa618cff2a14e'),
#   'forwards': 9,
#   'message': 'I. Musikkorps des Infanterie-Regiments "Groß-Deutschland" - Alte '
#              'Kameraden, 1936\n'
#              '\n'
#              'Source: InternetArchive\n'
#              '#music #germany #nsdap 〜 agartha'}
# { '_id': ObjectId('659db9a1cb4aa618cff2a14f'),
#   'forwards': 3,
#   'message': '#lyrics 〜 agartha'}
# { '_id': ObjectId('659db9a1cb4aa618cff2a150'),
#   'forwards': 13,
#   'message': 'General Paul von Hindenburg, Kaiser Wilhelm II and General Erich '
#              'Ludendorff in the Große Hauptquartier (Great Headquarters) '
#              'located in Pless Castle (Poland), 8 January 1917\n'
#              '\n'
#              'Source: wikimedia\n'
#              '#photo #germany #kaiserreich 〜 agartha'}
# { '_id': ObjectId('659db9a1cb4aa618cff2a151'),
#   'forwards': 4,
#   'message': 'Grande Orchestra Sinfonica di Milano - Inno a Roma, 1954\n'
#              '\n'
#              'Source: canzoneitaliana\n'
#              '#music #italy #dc 〜 agartha'}
# { '_id': ObjectId('659db9a1cb4aa618cff2a152'),
#   'forwards': 4,
#   'message': 'Beniamino Gigli - Inno a Roma, 1937\n'
#              '\n'
#              'Source: canzoneitaliana\n'
#              '#music #italy #pnf 〜 agartha'}
# { '_id': ObjectId('659db9a1cb4aa618cff2a153'),
#   'forwards': 5,
#   'message': 'Aldo Masseglia - Inno a Roma, 1938\n'
#              '\n'
#              'Source: canzoneitaliana\n'
#              '#music #italy #pnf 〜 agartha'}
# { '_id': ObjectId('659db9a1cb4aa618cff2a154'),
#   'forwards': 2,
#   'message': 'Source: Il Piave\n#lyrics 〜 agartha'}

# %% [markdown]
# ### Methods .count() and .distinct()
#
# With these methods we can count number of documents based on criterion, or gather distinct values for the field.
#
# Here we are going to work on another collection as these two methods can be time consuming if the fields are not indexed.
#
# We can observe, that when using the field "chat_id", the query is 60 times faster compared to using an unindexed field "phone". One can argue that for instance, number of distnict phones is 2.5 times larger than number of chat_ids, but on the other hand, here we shown that even for the field "contact" with only one value , querying by chat_id is more than 10 times faster!
#
# We can see similar results with .count as well.
#
# Importance of indexing will be discussed in the next section.

# %%
participants_collection = db["participants"]

# participants_number = participants_collection.count_documents({})
# print(participants_number)
start_time = time.time()

distinct_chats = participants_collection.distinct("chat_id")
print(f"Number of distinct chats: {len(distinct_chats)}")
end_time = time.time()
elapsed_time = end_time - start_time


# Print the distinct values and the elapsed time
print(f"Time taken: {elapsed_time} seconds")

start_time = time.time()

distinct_phones = participants_collection.distinct("phone")
print(f"Number of distinct phones: {len(distinct_phones)}")
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken: {elapsed_time} seconds")

start_time = time.time()

distinct_contacts = participants_collection.distinct("contact")
print(f"Number of distinct contacts: {len(distinct_contacts)}")
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken: {elapsed_time} seconds")
# Out:
# Number of distinct chats: 140
# Time taken: 0.003003835678100586 seconds
# Number of distinct phones: 458
# Time taken: 0.1979968547821045 seconds
# Number of distinct contacts: 1
# Time taken: 0.03899979591369629 seconds

# %%
# print chat_id for the next
print(distinct_chats[-10])
# Out:
# 1826873627

# %%
start_time = time.time()
participants_number = participants_collection.count_documents({"chat_id": 1826873627})
print(f"Number of participants based on chat ids: {(participants_number)}")
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken: {elapsed_time} seconds")

start_time = time.time()
participants_number = participants_collection.count_documents(
    {"phone": "4367764863157"}
)
print(f"Number of participants based on contact: {(participants_number)}")
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken: {elapsed_time} seconds")
# Out:
# Number of participants based on chat ids: 28
# Time taken: 0.0030121803283691406 seconds
# Number of participants based on contact: 3
# Time taken: 0.04696202278137207 seconds

# %% [markdown]
# ### Aggregation
#
# Here we use another way of querying MongoDB called aggregation. This can in some cases speed up the process as it can parallelize some filters from the piple line. Nevertheless, sometimes, it is not a good idea.

# %%
# Aggregation pipeline for counting based on chat_id
chat_id_pipeline = [
    {"$match": {"chat_id": 1826873627}},
    {"$count": "participants_count"},
]

# Aggregation pipeline for counting based on phone
stories_unavailable_pipeline = [
    {"$match": {"phone": "4367764863157"}},
    {"$count": "participants_count"},
]

start_time = time.time()
result_chat_id = list(participants_collection.aggregate(chat_id_pipeline))
participants_count_chat_id = (
    result_chat_id[0]["participants_count"] if result_chat_id else 0
)
end_time = time.time()
elapsed_time_chat_id = end_time - start_time

start_time = time.time()
result_stories_unavailable = list(
    participants_collection.aggregate(stories_unavailable_pipeline)
)
participants_count_stories_unavailable = (
    result_stories_unavailable[0]["participants_count"]
    if result_stories_unavailable
    else 0
)
end_time = time.time()
elapsed_time_stories_unavailable = end_time - start_time

print(f"Number of participants based on chat_id: {participants_count_chat_id}")
print(f"Time taken for chat_id: {elapsed_time_chat_id} seconds")

print(
    f"Number of participants based on stories_unavailable: {participants_count_stories_unavailable}"
)
print(f"Time taken for stories_unavailable: {elapsed_time_stories_unavailable} seconds")
# Out:
# Number of participants based on chat_id: 28
# Time taken for chat_id: 0.0019989013671875 seconds
# Number of participants based on stories_unavailable: 3
# Time taken for stories_unavailable: 0.0470128059387207 seconds

# %% [markdown]
# ## 1. Indexing
#
# Indexing can help a lot to speed up the query process. Some of the indices are created on the fly - while storing the data. Other indices can be created later on the existing collection.
#
# There are two types of indices:
#
#     - Single index is made on one field - thus querying based on that field will be optimized
#     - Compound index is created on two fields - this means we get optimal workflow on queries based on those two fields in the same time
#         - Compound index does not work optimally for querying based on just the second indexed field, although querying based on just the first indexed field, will provide faster data retrieval compared to no index
#
# Firstly, we are going to print indices for each collection.
#
#     - We see that collections "network" and "chats" does not have any indices beside the ones created automatically by MongoDB on ID field to distingish between them inside of a collection.
#     - Collection "participants" has single index on the field "chat_id"
#     - Collection "messages" has compound index on fields "date" and "peer_id.channel_id" - in that order!
#
# Then we make queries and examine their speed.
#
#     -

# %%
# Connect to MongoDB, path and namings are the same as the ones defined in the config-database.ini before the crawl was initiated
client = MongoClient("mongodb://localhost:27017/")
db = client["Telegram-090124-crawler"]
network_collection = db["network"]
messages_collection = db["messages"]
chats_collection = db["chats"]
participants_collection = db["participants"]

# %%
# List of collections
collections = ["network", "messages", "chats", "participants"]


# Function to print existing indexes for a collection
def print_indexes(collection_name):
    collection = db[collection_name]
    existing_indexes = collection.list_indexes()

    print(f"Indexes for collection '{collection_name}':")

    for index in existing_indexes:
        print(index)
    print("\n")


# Check indexes for each collection
for collection_name in collections:
    print_indexes(collection_name)
# Out:
# Indexes for collection 'network':
# SON([('v', 2), ('key', SON([('_id', 1)])), ('name', '_id_')])
#
#
# Indexes for collection 'messages':
# SON([('v', 2), ('key', SON([('_id', 1)])), ('name', '_id_')])
# SON([('v', 2), ('key', SON([('date', 1), ('peer_id.channel_id', 1)])), ('name', 'date_1_peer_id.channel_id_1')])
#
#
# Indexes for collection 'chats':
# SON([('v', 2), ('key', SON([('_id', 1)])), ('name', '_id_')])
#
#
# Indexes for collection 'participants':
# SON([('v', 2), ('key', SON([('_id', 1)])), ('name', '_id_')])
# SON([('v', 2), ('key', SON([('chat_id', 1)])), ('name', 'chat_id_1')])

# %%
date = datetime(2024, 1, 1)
cursor_date = messages_collection.find({"date": date})

print(len(list(cursor_date)))
# Out:
# 0

# %% [markdown]
# ### Compound index on date and chat_id field
#
# Now let's examine Compound index, but just on a "date" field, thus we are going to look at it as a single one.
#
# Firstly, let's choose a date or two, to retrieve messages. Cursor object, unless iterated or turned into a list, will not take anytime as we just initiated it. Thus, we need to measure an aciton on a cursor.
#
# We see that choosing a date as our filter, such as Jan 1 2023, it takes around 7 second to retrieve the data.

# %%
def get_speed(collection, query, projection):
    start_time = time.time()

    cursor = collection.find(query, projection)

    documents = list(cursor)

    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Number of documents retrieved: {len(documents)}")
    print(f"Time taken to list() retrieved documents: {elapsed_time} seconds")

    return documents

# %%
start_time = time.time()

date_start = datetime(2023, 1, 1, 0, 0, 0)
date_end = datetime(2023, 1, 2, 0, 0, 0)

cursor_date = messages_collection.find({"date": {"$gte": date_start, "$lte": date_end}})
print(f"Messages num: {len(list(cursor_date))}")

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to list(): {elapsed_time} seconds")


start_time = time.time()

cursor_date = messages_collection.find({"date": {"$gte": date_start, "$lte": date_end}})
mes_list = []
for item in cursor_date:
    mes_list.append(item)


print(f"Messages num: {len(list(mes_list))}")
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to iterate to a list: {elapsed_time} seconds")
# Out:
# Messages num: 18991
# Time taken to list(): 6.92830228805542 seconds
# Messages num: 18991
# Time taken to iterate to a list: 6.578845739364624 seconds

# %% [markdown]
# Let's try to filter now on an unindexed field "chat_id" (which is part of compund index, but second in order thus cannot be used). Now it iterates over every document in a collection to find the ones that belong to this chat_id. We see that it took almost 4 minutes for 30 million documents. Now, If our db become considerably larger (let's say 10 times in the next three weeks depending on the number of acocunts scraping), gathering information on these 15 chats would take much more time.
#
# Nevertheless, we see that if use 15 chat_ids to filter, query wil not last much longer.
#
# Important thing is that sorting cannot be done on fields that are not indexed.

# %%
start_time = time.time()
cursor_date = messages_collection.find({"peer_id.channel_id": 1826873627})
print(f"Messages num: {len(list(cursor_date))}")

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to list all messages: {elapsed_time} seconds")
# Out:
# Messages num: 355
# Time taken to list all messages: 224.6608145236969 seconds

# %%
# let's try 15 chats

chats_collections = db["chats"]
cursor_channels = chats_collections.find({}, {"full_chat.id"}).limit(15)
channel_ids = []

for item in cursor_channels:
    channel_ids.append(item.get("full_chat", {}).get("id"))

start_time = time.time()

cursor_date = messages_collection.find({"peer_id.channel_id": {"$in": channel_ids}})

print(f"Messages num: {len(list(cursor_date))}")

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to list() 2024: {elapsed_time} seconds")
# Out:
# Messages num: 19616
# Time taken to list() 2024: 250.95547032356262 seconds

# %% [markdown]
# Let's try to apply the same query with date and chat_id. Rememeber our compund index is on date,chat_id - in that order.
#
# We see it took considerably less time as it was able to sort our chat_ids after defining datetime filter. Nevertheless, One can argue that it would be more beneficial to have separate index on chat_id, or even reversed compund, depending on a usecase.

# %%
start_time = time.time()

date_start = datetime(2020, 1, 1, 0, 0, 0)
date_end = datetime(2024, 1, 1, 0, 0, 0)

cursor_date = messages_collection.find(
    {"date": {"$gte": date_start, "$lte": date_end}, "peer_id.channel_id": 1826873627}
)
print(f"Messages num: {len(list(cursor_date))}")

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to list() 2024: {elapsed_time} seconds")
# Out:
# Messages num: 304
# Time taken to list() 2024: 48.155343770980835 seconds

# %%
# Now let's try more channel_ids, we can find channels in chats colletction
chats_collections = db["chats"]
cursor_channels = chats_collections.find({}, {"full_chat.id"}).limit(15)
channel_ids = []

for item in cursor_channels:
    channel_ids.append(item.get("full_chat", {}).get("id"))

date_start = datetime(2020, 1, 1, 0, 0, 0)
date_end = datetime(2024, 1, 1, 0, 0, 0)

start_time = time.time()
cursor_date = messages_collection.find(
    {
        "date": {"$gte": date_start, "$lte": date_end},
        "peer_id.channel_id": {"$in": channel_ids},
    }
)
print(f"Messages num: {len(list(cursor_date))}")

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to list() 2024: {elapsed_time} seconds")
# Out:
# Messages num: 11279
# Time taken to list() 2024: 33.49662733078003 seconds

# %%
# let's skip frist 15, and use next 15, but also show that the order of fields does not matter, also let's now use 8 years
chats_collections = db["chats"]
cursor_channels = chats_collections.find({}, {"full_chat.id"}).skip(15).limit(15)
channel_ids = []

for item in cursor_channels:
    channel_ids.append(item.get("full_chat", {}).get("id"))

date_start = datetime(2016, 1, 1, 0, 0, 0)
date_end = datetime(2024, 1, 1, 0, 0, 0)

start_time = time.time()
cursor_date = messages_collection.find(
    {
        "peer_id.channel_id": {"$in": channel_ids},
        "date": {"$gte": date_start, "$lte": date_end},
    }
)
print(f"Messages num: {len(list(cursor_date))}")

end_time = time.time()
elapsed_time = end_time - start_time
print(
    f"Time taken to list() 15 chats based on datetime criteria: {elapsed_time} seconds"
)
# Out:
# Messages num: 32305
# Time taken to list() 15 chats based on datetime criteria: 60.304965019226074 seconds

# %% [markdown]
# Finally, let's try date with another field that is not chat_id. We are going to parse messages and find some messages that were forwarded from another chat, and extract that chat. One might argue we could use aggregation pipeline for this query as well.
#
# We see that our query is still very slow. We can easily access all of the dates, but it takes time to iterate over non-indexed field.

# %%
cursor = messages_collection.find(
    {"fwd_from.from_id.channel_id": {"$ne": None}}, {"fwd_from.from_id.channel_id": 1}
).limit(20)

fwd_list = set()
for document in cursor:
    fwd_list.add(document.get("fwd_from", {}).get("from_id", {}).get("channel_id"))
fwd_list = list(fwd_list)
print(len(fwd_list))

date_start = datetime(2016, 1, 1, 0, 0, 0)
date_end = datetime(2024, 1, 1, 0, 0, 0)

start_time = time.time()
cursor_date = messages_collection.find(
    {
        "fwd_from.from_id.channel_id": {"$in": fwd_list},
        "date": {"$gte": date_start, "$lte": date_end},
    }
)
print(f"Messages num: {len(list(cursor_date))}")

end_time = time.time()
elapsed_time = end_time - start_time
print(
    f"Time taken to list() 15 chats based on datetime criteria: {elapsed_time} seconds"
)
# Out:
# 5
# Messages num: 4982
# Time taken to list() 15 chats based on datetime criteria: 787.9138038158417 seconds

# %% [markdown]
# In the next cell, we parmetrized our query with the date in front of fwd chat_id.

# %%
cursor = messages_collection.find(
    {"fwd_from.from_id.channel_id": {"$ne": None}}, {"fwd_from.from_id.channel_id": 1}
).limit(5000)

fwd_list = set()
for document in cursor:
    fwd_list.add(document.get("fwd_from", {}).get("from_id", {}).get("channel_id"))
fwd_list = list(fwd_list)
print(len(fwd_list))

date_start = datetime(2016, 1, 1, 0, 0, 0)
date_end = datetime(2024, 1, 1, 0, 0, 0)

start_time = time.time()
cursor_date = messages_collection.find(
    {
        "date": {"$gte": date_start, "$lte": date_end},
        "fwd_from.from_id.channel_id": {"$in": fwd_list},
    }
)
print(f"Messages num: {len(list(cursor_date))}")

end_time = time.time()
elapsed_time = end_time - start_time
print(
    f"Time taken to list() 15 chats based on datetime criteria: {elapsed_time} seconds"
)
# Out:
# 77
# Messages num: 5004
# Time taken to list() 15 chats based on datetime criteria: 1.7020316123962402 seconds

# %%
start_time = time.time()

cursor_date = messages_collection.find(
    {"fwd_from.from_id.channel_id": {"$in": fwd_list}}
)

print(f"Messages num: {len(list(cursor_date))}")

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to list() 2024: {elapsed_time} seconds")
# Out:
# Messages num: 5014
# Time taken to list() 2024: 1.52162504196167 seconds

# %% [markdown]
# Next, let's talk about sorting. We can see in one of the previous cells about indices this information:
#
#     SON([('v', 2), ('key', SON([('date', 1), ('peer_id.channel_id', 1)])), ('name', 'date_1_peer_id.channel_id_1')])
#
#
# "SON([('date', 1)" means that our date is sorted in ascending order. If there would be number -1, it would mean descending.
#
# The choise of ascending/descending on a single field, means nothing, as MongoDB can traverse the index in either direction. Nevertheless, it means a lot for compund index. as Mongo db will first sort the first field, and then for each first field it will sort the second one. In this case of compund index on a date and chat_id field, it will sort first the date, and then in each date, it will sort chat_id. This does not make a lot of sense, as our date field is very unique due to time. Nevertheless, It works really well, although I am not sure if it would be even faster if we would have two separate indices. I can assume that as db grows, the choise of wheteher to use compound index or not, will depend on a use case.
#
# Furthermore, we could definitely define another field named date, thus we will not have that many unique values.

# %% [markdown]
# ### Create a single index on an existing field
#
# Now, we can see that our channel_id from fwd_from.from_id.channel_id works much better! Even better than the compound index!
#
# Be cautious with index creation as this can slow down writing process, as well as writing. Therefore,

# %%
start_time = time.time()
messages_collection.create_index("fwd_from.from_id.channel_id")
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to create index: {elapsed_time} seconds")
# Out:
# Time taken to create index: 265.11340498924255 seconds

# %%
start_time = time.time()
cursor = messages_collection.find(
    {"fwd_from.from_id.channel_id": {"$ne": None}}, {"fwd_from.from_id.channel_id": 1}
).limit(2000)


for document in cursor:
    fwd_list.append(document.get("fwd_from", {}).get("from_id", {}).get("channel_id"))

end_time = time.time()
elapsed_time = end_time - start_time
print(
    f"Time taken to list() 10000 chats ids from indexed field: {elapsed_time} seconds"
)

fwd_list = list(set(fwd_list))
print(len(fwd_list))

date_start = datetime(2014, 1, 1, 0, 0, 0)
date_end = datetime(2024, 1, 1, 0, 0, 0)

start_time = time.time()
cursor_date = messages_collection.find(
    {
        "date": {"$gte": date_start, "$lte": date_end},
        "fwd_from.from_id.channel_id": {"$in": fwd_list},
    }
)
print(f"Messages num: {len(list(cursor_date))}")

end_time = time.time()
elapsed_time = end_time - start_time
print(
    f"Time taken to list() 15 chats based on datetime criteria: {elapsed_time} seconds"
)
# Out:
# Time taken to list() 10000 chats ids from indexed field: 0.06733179092407227 seconds
# 55
# Messages num: 2315
# Time taken to list() 15 chats based on datetime criteria: 0.7402799129486084 seconds

# %% [markdown]
# Finally, lets compare compound index vs two single indices.

# %%
date_start = datetime(2020, 1, 1, 0, 0, 0)
date_end = datetime(2024, 1, 1, 0, 0, 0)

start_time = time.time()
cursor_date = messages_collection.find(
    {
        "date": {"$gte": date_start, "$lte": date_end},
        "fwd_from.from_id.channel_id": {"$in": fwd_list},
    }
)
print(f"Messages num: {len(list(cursor_date))}")

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to list() 2024: {elapsed_time} seconds")
# Out:
# Messages num: 2189
# Time taken to list() 2024: 0.5249917507171631 seconds

# %% [markdown]
# # 2. Projection
#
# Projection is used to filter how many fields will be retrieved. Here we can see that, whether we use index or not, speed will be affected by the size of transferred data from MongoDB to python, as well. Thus, it is important to use projecion if the document is large.
#
# Here, we have decided to exclude all messages that were not forwarded from other chats, thus we did not utilized index effectively, as we could have filter it more.
#
# Nevertheless, first, we tried to retrieve all the data based on criteria, and after that: one and two fields respectively. We will use .limit() function to retrieve only first 100,000 matches.

# %%
start_time = time.time()
cursor = messages_collection.find({"fwd_from.from_id.channel_id": {"$ne": None}}).limit(
    100000
)

all_messages = list(cursor)
print(f"Messages num: {len(all_messages)}")

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to list() whole message: {elapsed_time} seconds")
# Out:
# Messages num: 100000
# Time taken to list() whole message: 61.28468871116638 seconds

# %%
for index, message in enumerate(all_messages):
    if index < 5:
        pprint(message, indent=1)
# Out:
# {'_': 'Message',
#  '_id': ObjectId('659dd1e5cb4aa618cf047dad'),
#  'date': datetime.datetime(2022, 1, 25, 20, 55, 16),
#  'edit_date': datetime.datetime(2022, 1, 25, 20, 55, 19),
#  'edit_hide': True,
#  'entities': [{'_': 'MessageEntityMention', 'length': 17, 'offset': 50},
#               {'_': 'MessageEntityUrl', 'length': 66, 'offset': 69}],
#  'forwards': 5,
#  'from_id': None,
#  'from_scheduled': False,
#  'fwd_from': {'_': 'MessageFwdHeader',
#               'channel_post': 12114,
#               'date': datetime.datetime(2022, 1, 25, 13, 4, 46),
#               'from_id': {'_': 'PeerChannel', 'channel_id': 1000023516},
#               'from_name': None,
#               'imported': False,
#               'post_author': None,
#               'psa_type': None,
#               'saved_from_msg_id': None,
#               'saved_from_peer': None},
#  'grouped_id': None,
#  'id': 20887,
#  'legacy': False,
#  'media': {'_': 'MessageMediaWebPage',
#            'webpage': {'_': 'WebPage',
#                        'attributes': [],
#                        'author': None,
#                        'cached_page': None,
#                        'description': 'El cultivo hidropónico casero tiene '
#                                       'muchas ventajas: un suministro regular '
#                                       'de productos frescos y nutritivos.',
#                        'display_url': 'ecoinventos.com/como-crear-un-sistema-hidroponico-casero-con-168-plantas',
#                        'document': None,
#                        'duration': None,
#                        'embed_height': None,
#                        'embed_type': None,
#                        'embed_url': None,
#                        'embed_width': None,
#                        'hash': 0,
#                        'id': 573117916097464239,
#                        'photo': {'_': 'Photo',
#                                  'access_hash': -3742224630227041839,
#                                  'date': datetime.datetime(2018, 6, 2, 23, 20, 9),
#                                  'dc_id': 4,
#                                  'file_reference': b'\x00e\x9d\xd1'
#                                                    b'\x11\x97\x98\xbc\x872\x95!'
#                                                    b'V\xaa\xcb[B(\xe3\xd4\xc6',
#                                  'has_stickers': False,
#                                  'id': 5808820702814513101,
#                                  'sizes': [{'_': 'PhotoSize',
#                                             'h': 67,
#                                             'size': 1994,
#                                             'type': 's',
#                                             'w': 90},
#                                            {'_': 'PhotoSize',
#                                             'h': 240,
#                                             'size': 30787,
#                                             'type': 'm',
#                                             'w': 320},
#                                            {'_': 'PhotoSize',
#                                             'h': 480,
#                                             'size': 76564,
#                                             'type': 'x',
#                                             'w': 640}],
#                                  'video_sizes': []},
#                        'site_name': 'EcoInventos',
#                        'title': 'Cómo hacer un sistema hidropónico casero con '
#                                 '168 plantas',
#                        'type': 'photo',
#                        'url': 'https://ecoinventos.com/como-hacer-sistema-hidroponico-nft-casero/'}},
#  'media_unread': False,
#  'mentioned': False,
#  'message': 'Cómo hacer un sistema hidropónico NFT casero 🌶🍅\n'
#             '@DIY_Hazlotumismo\n'
#             '\n'
#             'https://ecoinventos.com/como-hacer-sistema-hidroponico-nft-casero/',
#  'noforwards': False,
#  'out': False,
#  'peer_id': {'_': 'PeerChannel', 'channel_id': 1391166244},
#  'pinned': False,
#  'post': True,
#  'post_author': None,
#  'reactions': None,
#  'replies': {'_': 'MessageReplies',
#              'channel_id': 1384464252,
#              'comments': True,
#              'max_id': 36183,
#              'read_max_id': None,
#              'recent_repliers': [{'_': 'PeerUser', 'user_id': 1084440567}],
#              'replies': 1,
#              'replies_pts': 358807},
#  'reply_markup': None,
#  'reply_to': None,
#  'restriction_reason': [],
#  'silent': False,
#  'ttl_period': None,
#  'via_bot_id': None,
#  'views': 792}
# {'_': 'Message',
#  '_id': ObjectId('659f06efcb4aa618cf18fb6c'),
#  'date': datetime.datetime(2021, 6, 11, 9, 43),
#  'edit_date': None,
#  'edit_hide': False,
#  'entities': [{'_': 'MessageEntityMention', 'length': 17, 'offset': 110},
#               {'_': 'MessageEntityUrl', 'length': 46, 'offset': 129}],
#  'forwards': 89,
#  'from_id': None,
#  'from_scheduled': False,
#  'fwd_from': {'_': 'MessageFwdHeader',
#               'channel_post': 10793,
#               'date': datetime.datetime(2021, 6, 8, 17, 5, 1),
#               'from_id': {'_': 'PeerChannel', 'channel_id': 1000023516},
#               'from_name': None,
#               'imported': False,
#               'post_author': None,
#               'psa_type': None,
#               'saved_from_msg_id': None,
#               'saved_from_peer': None},
#  'grouped_id': None,
#  'id': 6467,
#  'legacy': False,
#  'media': {'_': 'MessageMediaWebPage',
#            'webpage': {'_': 'WebPage',
#                        'attributes': [],
#                        'author': None,
#                        'cached_page': None,
#                        'description': 'Según WCS pueden aumentar un 500% la '
#                                       'producción anual de energía respecto a '
#                                       'los aerogeneradores convencionales, con '
#                                       'una vida útil de 50 años.',
#                        'display_url': 'ecoinventos.com/wind-catching-systems',
#                        'document': None,
#                        'duration': None,
#                        'embed_height': None,
#                        'embed_type': None,
#                        'embed_url': None,
#                        'embed_width': None,
#                        'hash': 0,
#                        'id': 573117915367139864,
#                        'photo': {'_': 'Photo',
#                                  'access_hash': 8604856818596923922,
#                                  'date': datetime.datetime(2021, 6, 8, 11, 7, 6),
#                                  'dc_id': 4,
#                                  'file_reference': b'\x00e\x9f\x06\xb246+'
#                                                    b'\xfe\x14-\x96'
#                                                    b'\xb1\xfa\x1c\x95'
#                                                    b'\x02W\xb4\x7f\x0c',
#                                  'has_stickers': False,
#                                  'id': 5910262813824232443,
#                                  'sizes': [{'_': 'PhotoStrippedSize',
#                                             'bytes': b'\x01\x17(\xbf'
#                                                      b'\xb0\xfa\xd3H'
#                                                      b'!\x80\xf5\xa8|\xf3L3'
#                                                      b'\r\xe2\xa8\x82'
#                                                      b'\xce\x18\x1e\x82'
#                                                      b'\x97\x07\xb8\x15'
#                                                      b'\x07\x9b\xde\x8f'
#                                                      b'4\xd0\x05\x8f'
#                                                      b'\x9b\xb2\x8a*'
#                                                      b'\xb7\x9cE\x14'
#                                                      b'\xec\x17*\x0b'
#                                                      b'\xa2\xa7\x1bF'
#                                                      b'=\x8d\x02\xee>KE\x91'
#                                                      b'\x8a(\xa9(g\x9e\xddT'
#                                                      b'\xb0_Bh\x13\xb8\xee\x0f'
#                                                      b'\xe1E\x14\xc4'
#                                                      b'8\xc8\xa4\x96'
#                                                      b'/\x83\xe9\x8a'
#                                                      b'(\xa2\x98\x1f',
#                                             'type': 'i'},
#                                            {'_': 'PhotoSize',
#                                             'h': 180,
#                                             'size': 18171,
#                                             'type': 'm',
#                                             'w': 320},
#                                            {'_': 'PhotoSize',
#                                             'h': 450,
#                                             'size': 101956,
#                                             'type': 'x',
#                                             'w': 800},
#                                            {'_': 'PhotoSizeProgressive',
#                                             'h': 563,
#                                             'sizes': [6489,
#                                                       8703,
#                                                       51362,
#                                                       92631,
#                                                       102336],
#                                             'type': 'y',
#                                             'w': 1000}],
#                                  'video_sizes': []},
#                        'site_name': 'EcoInventos',
#                        'title': 'Gigantescos aerogeneradores flotantes de 324 '
#                                 'metros capaces de suministrar energía a '
#                                 '80.000 hogares cada uno',
#                        'type': 'photo',
#                        'url': 'https://ecoinventos.com/wind-catching-systems/'}},
#  'media_unread': False,
#  'mentioned': False,
#  'message': 'Gigantescos aerogeneradores flotantes de 324 metros capaces de '
#             'suministrar energía a 80.000 hogares cada uno.\n'
#             '@Futuro_renovable\n'
#             '\n'
#             'https://ecoinventos.com/wind-catching-systems/',
#  'noforwards': False,
#  'out': False,
#  'peer_id': {'_': 'PeerChannel', 'channel_id': 1417414502},
#  'pinned': False,
#  'post': True,
#  'post_author': None,
#  'reactions': None,
#  'replies': None,
#  'reply_markup': None,
#  'reply_to': None,
#  'restriction_reason': [],
#  'silent': False,
#  'ttl_period': None,
#  'via_bot_id': None,
#  'views': 19276}
# {'_': 'Message',
#  '_id': ObjectId('65a4a0d93a281ea2115121de'),
#  'date': datetime.datetime(2023, 5, 18, 16, 57, 54),
#  'edit_date': datetime.datetime(2023, 5, 18, 16, 58, 16),
#  'edit_hide': True,
#  'entities': [],
#  'forwards': 5,
#  'from_id': None,
#  'from_scheduled': False,
#  'fwd_from': {'_': 'MessageFwdHeader',
#               'channel_post': 3272,
#               'date': datetime.datetime(2023, 5, 18, 16, 25, 34),
#               'from_id': {'_': 'PeerChannel', 'channel_id': 1000064590},
#               'from_name': None,
#               'imported': False,
#               'post_author': None,
#               'psa_type': None,
#               'saved_from_msg_id': None,
#               'saved_from_peer': None},
#  'grouped_id': None,
#  'id': 7999,
#  'legacy': False,
#  'media': None,
#  'media_unread': False,
#  'mentioned': False,
#  'message': 'اطلعت على مقطع للأخ دانيال حقيقتجو بعنوان\n'
#             'Is Your Zakat Funding the Most Un-Islamic "Islamic" Graduate '
#             'School? (Bayan)\n'
#             'يُحَذِّرُ فيه من مؤسسة تأخذ من المسلمين في أمريكا أموال صدقات '
#             'وزكاة لتخرج مسلمين مؤثرين في المجتمع حسب زعمها.\n'
#             'لا أريد أن أناقش هنا إن كان الأخ دانيال عنده بعض الأخطاء في '
#             'فيديوهاته بشكل عام أم لا. لكنه بلا شك صوت من الأصوات الناصحة '
#             'الصريحة، وصوابه أكثر من خطئه، وقد بين في هذا الفيديو، بالأدلة '
#             'صوتاً وصورة، أن مثل هذه المؤسسة يجب الحذر والتحذير منها. وأعلم '
#             'أنها ليست الوحيدة في أميريكا التي يعطيها المسلمون من أموال زكاتهم '
#             'ثم تذهب لما يؤذي الإسلام ولا ينفعه! \n'
#             'فليكن إخواننا هناك حريصين متحرين لئلا يكونوا شركاء في الوزر.',
#  'noforwards': False,
#  'out': False,
#  'peer_id': {'_': 'PeerChannel', 'channel_id': 1211160527},
#  'pinned': False,
#  'post': True,
#  'post_author': None,
#  'reactions': {'_': 'MessageReactions',
#                'can_see_list': False,
#                'min': False,
#                'recent_reactions': [],
#                'results': [{'_': 'ReactionCount',
#                             'chosen_order': None,
#                             'count': 238,
#                             'reaction': {'_': 'ReactionEmoji',
#                                          'emoticon': '❤'}},
#                            {'_': 'ReactionCount',
#                             'chosen_order': None,
#                             'count': 31,
#                             'reaction': {'_': 'ReactionEmoji',
#                                          'emoticon': '👍'}},
#                            {'_': 'ReactionCount',
#                             'chosen_order': None,
#                             'count': 7,
#                             'reaction': {'_': 'ReactionEmoji',
#                                          'emoticon': '🔥'}}]},
#  'replies': None,
#  'reply_markup': None,
#  'reply_to': None,
#  'restriction_reason': [],
#  'silent': False,
#  'ttl_period': None,
#  'via_bot_id': None,
#  'views': 8338}
# {'_': 'Message',
#  '_id': ObjectId('659dc94dcb4aa618cffd1c94'),
#  'date': datetime.datetime(2021, 2, 18, 21, 55, 35),
#  'edit_date': datetime.datetime(2022, 11, 9, 5, 53, 55),
#  'edit_hide': True,
#  'entities': [{'_': 'MessageEntityMention', 'length': 9, 'offset': 84}],
#  'forwards': 17,
#  'from_id': None,
#  'from_scheduled': False,
#  'fwd_from': {'_': 'MessageFwdHeader',
#               'channel_post': 2764,
#               'date': datetime.datetime(2021, 2, 18, 21, 55, 30),
#               'from_id': {'_': 'PeerChannel', 'channel_id': 1000093690},
#               'from_name': None,
#               'imported': False,
#               'post_author': None,
#               'psa_type': None,
#               'saved_from_msg_id': None,
#               'saved_from_peer': None},
#  'grouped_id': None,
#  'id': 546,
#  'legacy': False,
#  'media': {'_': 'MessageMediaPhoto',
#            'photo': {'_': 'Photo',
#                      'access_hash': 7313255988085779871,
#                      'date': datetime.datetime(2021, 2, 18, 21, 55, 30),
#                      'dc_id': 2,
#                      'file_reference': b'\x02V\xab2\xdb\x00\x00\x02"e\x9d\xc9'
#                                        b'KeS\xcf\xd9\xeb^4\x1f\xd6\xb4\xc1'
#                                        b'\x8e\xf5\\w\xa1',
#                      'has_stickers': False,
#                      'id': 5294207574062772280,
#                      'sizes': [{'_': 'PhotoStrippedSize',
#                                 'bytes': b'\x01\x16(\xa8\x01*\xe7\xe6\xf9Fx\x14'
#                                          b'\xeb(|\xc3\xbeL\x91\xd8f\x99\xbf`'
#                                          b'q\x82w\x0cu\xc5Ob\xc0D(\x02'
#                                          b'\xef\x94\x84\x7f\xab\x8f\xfe\xf9'
#                                          b'\x15V\xea\x10G\x00)\xf5\x1cU\xc1 '
#                                          b'\xc5W\xb8|\x83@\x19\xd1'
#                                          b'\x9c\x06\r\x9c\x83\xebE.'
#                                          b'G\x98\xff\x00Z(\x01\xa6\x88$1\xb6'
#                                          b';\x1a(\xa0\x0b^\x7f\xb1'
#                                          b'\xa8\xa6\x98\xe3\x8e\xb4Q@'
#                                          b'\x11@\xbb\x98\x82h\xa2\x8a\x00',
#                                 'type': 'i'},
#                                {'_': 'PhotoSize',
#                                 'h': 179,
#                                 'size': 11061,
#                                 'type': 'm',
#                                 'w': 320},
#                                {'_': 'PhotoSize',
#                                 'h': 448,
#                                 'size': 45664,
#                                 'type': 'x',
#                                 'w': 800},
#                                {'_': 'PhotoSizeProgressive',
#                                 'h': 717,
#                                 'sizes': [10820, 24440, 32781, 52321, 92018],
#                                 'type': 'y',
#                                 'w': 1280}],
#                      'video_sizes': []},
#            'spoiler': False,
#            'ttl_seconds': None},
#  'media_unread': False,
#  'mentioned': False,
#  'message': "The first image from NASA's Perseverance Mars rover just moments "
#             'after it landed. \n'
#             '\n'
#             '@American',
#  'noforwards': False,
#  'out': False,
#  'peer_id': {'_': 'PeerChannel', 'channel_id': 1454060251},
#  'pinned': False,
#  'post': True,
#  'post_author': None,
#  'reactions': {'_': 'MessageReactions',
#                'can_see_list': False,
#                'min': False,
#                'recent_reactions': [],
#                'results': [{'_': 'ReactionCount',
#                             'chosen_order': None,
#                             'count': 2,
#                             'reaction': {'_': 'ReactionEmoji',
#                                          'emoticon': '👍'}}]},
#  'replies': None,
#  'reply_markup': None,
#  'reply_to': None,
#  'restriction_reason': [],
#  'silent': False,
#  'ttl_period': None,
#  'via_bot_id': None,
#  'views': 10951}
# {'_': 'Message',
#  '_id': ObjectId('659dc94dcb4aa618cffd1c9a'),
#  'date': datetime.datetime(2021, 2, 17, 8, 11, 33),
#  'edit_date': datetime.datetime(2023, 1, 8, 22, 0, 22),
#  'edit_hide': True,
#  'entities': [{'_': 'MessageEntityMention', 'length': 10, 'offset': 0},
#               {'_': 'MessageEntityMention', 'length': 9, 'offset': 68}],
#  'forwards': 14,
#  'from_id': None,
#  'from_scheduled': False,
#  'fwd_from': {'_': 'MessageFwdHeader',
#               'channel_post': 2753,
#               'date': datetime.datetime(2021, 2, 17, 7, 16, 4),
#               'from_id': {'_': 'PeerChannel', 'channel_id': 1000093690},
#               'from_name': None,
#               'imported': False,
#               'post_author': None,
#               'psa_type': None,
#               'saved_from_msg_id': None,
#               'saved_from_peer': None},
#  'grouped_id': None,
#  'id': 540,
#  'legacy': False,
#  'media': {'_': 'MessageMediaPhoto',
#            'photo': {'_': 'Photo',
#                      'access_hash': 7275343209281997652,
#                      'date': datetime.datetime(2021, 2, 17, 7, 16, 4),
#                      'dc_id': 2,
#                      'file_reference': b'\x02V\xab2\xdb\x00\x00\x02'
#                                        b'\x1ce\x9d\xc9K\xfd\xc3\xa9\xc9C\xea/'
#                                        b'\x1b;l\xb2\x98Q4\xde\xbe',
#                      'has_stickers': False,
#                      'id': 5289616773714391487,
#                      'sizes': [{'_': 'PhotoStrippedSize',
#                                 'bytes': b'\x01\x18(\xc7\xa5\xc5\x14\xf8'
#                                          b'\xd41\xc18\x14\x01`\xa4f\xcf\x85P'
#                                          b'\xe0gwz\xa9\xde\xa6 +\x95\x03 '
#                                          b'\xd3$@\xbc\x83@6GE-\x14\x00'
#                                          b'\xb4\xe1\xc7>\xb4Q@\x0b'
#                                          b'\x9f\x9e\x90\xe0\x83\xcf4QL\x06QE'
#                                          b'\x14\x80',
#                                 'type': 'i'},
#                                {'_': 'PhotoSize',
#                                 'h': 197,
#                                 'size': 8668,
#                                 'type': 'm',
#                                 'w': 320},
#                                {'_': 'PhotoSizeProgressive',
#                                 'h': 400,
#                                 'sizes': [3606, 6664, 9039, 14156, 27918],
#                                 'type': 'x',
#                                 'w': 650}],
#                      'video_sizes': []},
#            'spoiler': False,
#            'ttl_seconds': None},
#  'media_unread': False,
#  'mentioned': False,
#  'message': "@Elon_Musk's reign was brief. Jeff Bezos is world's richest "
#             'again \n'
#             '\n'
#             '@American',
#  'noforwards': False,
#  'out': False,
#  'peer_id': {'_': 'PeerChannel', 'channel_id': 1454060251},
#  'pinned': False,
#  'post': True,
#  'post_author': None,
#  'reactions': {'_': 'MessageReactions',
#                'can_see_list': False,
#                'min': False,
#                'recent_reactions': [],
#                'results': [{'_': 'ReactionCount',
#                             'chosen_order': None,
#                             'count': 1,
#                             'reaction': {'_': 'ReactionEmoji',
#                                          'emoticon': '👍'}}]},
#  'replies': None,
#  'reply_markup': None,
#  'reply_to': None,
#  'restriction_reason': [],
#  'silent': False,
#  'ttl_period': None,
#  'via_bot_id': None,
#  'views': 12265}

# %%
start_time = time.time()
cursor = messages_collection.find(
    {"fwd_from.from_id.channel_id": {"$ne": None}},
    {"message": 1, "fwd_from.from_id.channel_id": 1},
).limit(100000)
messages_subset = list(cursor)
print(f"Messages num: {len(messages_subset)}")

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to list() two fields of a message: {elapsed_time} seconds")
# Out:
# Messages num: 100000
# Time taken to list() two fields of a message: 2.521620273590088 seconds

# %%
for index, message in enumerate(messages_subset):
    if index < 5:
        pprint(message, indent=1)
# Out:
# {'_id': ObjectId('659dd1e5cb4aa618cf047dad'),
#  'fwd_from': {'from_id': {'channel_id': 1000023516}},
#  'message': 'Cómo hacer un sistema hidropónico NFT casero 🌶🍅\n'
#             '@DIY_Hazlotumismo\n'
#             '\n'
#             'https://ecoinventos.com/como-hacer-sistema-hidroponico-nft-casero/'}
# {'_id': ObjectId('659f06efcb4aa618cf18fb6c'),
#  'fwd_from': {'from_id': {'channel_id': 1000023516}},
#  'message': 'Gigantescos aerogeneradores flotantes de 324 metros capaces de '
#             'suministrar energía a 80.000 hogares cada uno.\n'
#             '@Futuro_renovable\n'
#             '\n'
#             'https://ecoinventos.com/wind-catching-systems/'}
# {'_id': ObjectId('65a4a0d93a281ea2115121de'),
#  'fwd_from': {'from_id': {'channel_id': 1000064590}},
#  'message': 'اطلعت على مقطع للأخ دانيال حقيقتجو بعنوان\n'
#             'Is Your Zakat Funding the Most Un-Islamic "Islamic" Graduate '
#             'School? (Bayan)\n'
#             'يُحَذِّرُ فيه من مؤسسة تأخذ من المسلمين في أمريكا أموال صدقات '
#             'وزكاة لتخرج مسلمين مؤثرين في المجتمع حسب زعمها.\n'
#             'لا أريد أن أناقش هنا إن كان الأخ دانيال عنده بعض الأخطاء في '
#             'فيديوهاته بشكل عام أم لا. لكنه بلا شك صوت من الأصوات الناصحة '
#             'الصريحة، وصوابه أكثر من خطئه، وقد بين في هذا الفيديو، بالأدلة '
#             'صوتاً وصورة، أن مثل هذه المؤسسة يجب الحذر والتحذير منها. وأعلم '
#             'أنها ليست الوحيدة في أميريكا التي يعطيها المسلمون من أموال زكاتهم '
#             'ثم تذهب لما يؤذي الإسلام ولا ينفعه! \n'
#             'فليكن إخواننا هناك حريصين متحرين لئلا يكونوا شركاء في الوزر.'}
# {'_id': ObjectId('659dc94dcb4aa618cffd1c94'),
#  'fwd_from': {'from_id': {'channel_id': 1000093690}},
#  'message': "The first image from NASA's Perseverance Mars rover just moments "
#             'after it landed. \n'
#             '\n'
#             '@American'}
# {'_id': ObjectId('659dc94dcb4aa618cffd1c9a'),
#  'fwd_from': {'from_id': {'channel_id': 1000093690}},
#  'message': "@Elon_Musk's reign was brief. Jeff Bezos is world's richest "
#             'again \n'
#             '\n'
#             '@American'}

# %% [markdown]
# # 3. Use aggregation, log slow queries, .explain()
#
# There might be some queries where aggregation would help fetch result faster as we could use query operations in parallel.
#
# We can set profiling levels to log info about slow queries.
#
# Also we can utilize .explain() method before running the query.
#
# Finally, if we query one field more than another,

# %%
explanation = (
    messages_collection.find({"fwd_from.from_id.channel_id": {"$ne": None}})
    .limit(100000)
    .explain()
)

pprint(explanation, indent=1)
# Out:
# {'command': {'$db': 'Telegram-090124-crawler',
#              'filter': {'fwd_from.from_id.channel_id': {'$ne': None}},
#              'find': 'messages',
#              'limit': 100000,
#              'singleBatch': True},
#  'executionStats': {'allPlansExecution': [],
#                     'executionStages': {'closes': 1,
#                                         'executionTimeMillisEstimate': 258,
#                                         'inputStage': {'closes': 1,
#                                                        'collectionScans': 0,
#                                                        'collectionSeeks': 100000,
#                                                        'executionTimeMillisEstimate': 258,
#                                                        'indexScans': 0,
#                                                        'indexSeeks': 1,
#                                                        'indexesUsed': ['fwd_from.from_id.channel_id_1'],
#                                                        'innerCloses': 1,
#                                                        'innerOpens': 100000,
#                                                        'innerStage': {'closes': 1,
#                                                                       'executionTimeMillisEstimate': 33,
#                                                                       'inputStage': {'closes': 1,
#                                                                                      'executionTimeMillisEstimate': 33,
#                                                                                      'fields': [],
#                                                                                      'indexIdentSlot': 6,
#                                                                                      'indexKeyPatternSlot': 8,
#                                                                                      'indexKeySlot': 7,
#                                                                                      'isEOF': 0,
#                                                                                      'nReturned': 100000,
#                                                                                      'numReads': 100000,
#                                                                                      'opens': 100000,
#                                                                                      'outputSlots': [],
#                                                                                      'planNodeId': 2,
#                                                                                      'recordIdSlot': 10,
#                                                                                      'recordSlot': 9,
#                                                                                      'restoreState': 100,
#                                                                                      'saveState': 100,
#                                                                                      'seekKeySlot': 4,
#                                                                                      'snapshotIdSlot': 5,
#                                                                                      'stage': 'seek'},
#                                                                       'isEOF': 1,
#                                                                       'limit': 1,
#                                                                       'nReturned': 100000,
#                                                                       'opens': 100000,
#                                                                       'planNodeId': 2,
#                                                                       'restoreState': 100,
#                                                                       'saveState': 100,
#                                                                       'stage': 'limit'},
#                                                        'isEOF': 0,
#                                                        'nReturned': 100000,
#                                                        'opens': 1,
#                                                        'outerCorrelated': [4,
#                                                                            5,
#                                                                            6,
#                                                                            7,
#                                                                            8],
#                                                        'outerProjects': [],
#                                                        'outerStage': {'closes': 1,
#                                                                       'executionTimeMillisEstimate': 225,
#                                                                       'indexIdentSlot': 6,
#                                                                       'indexKeySlot': 7,
#                                                                       'indexKeysToInclude': '00000000000000000000000000000000',
#                                                                       'indexName': 'fwd_from.from_id.channel_id_1',
#                                                                       'isEOF': 0,
#                                                                       'keysExamined': 100001,
#                                                                       'nReturned': 100000,
#                                                                       'numReads': 100001,
#                                                                       'opens': 1,
#                                                                       'outputSlots': [],
#                                                                       'planNodeId': 1,
#                                                                       'recordIdSlot': 4,
#                                                                       'restoreState': 100,
#                                                                       'saveState': 100,
#                                                                       'seeks': 2,
#                                                                       'snapshotIdSlot': 5,
#                                                                       'stage': 'ixscan_generic'},
#                                                        'planNodeId': 2,
#                                                        'restoreState': 100,
#                                                        'saveState': 100,
#                                                        'stage': 'nlj',
#                                                        'totalDocsExamined': 100000,
#                                                        'totalKeysExamined': 100001},
#                                         'isEOF': 1,
#                                         'limit': 100000,
#                                         'nReturned': 100000,
#                                         'opens': 1,
#                                         'planNodeId': 3,
#                                         'restoreState': 100,
#                                         'saveState': 100,
#                                         'stage': 'limit'},
#                     'executionSuccess': True,
#                     'executionTimeMillis': 263,
#                     'nReturned': 100000,
#                     'totalDocsExamined': 100000,
#                     'totalKeysExamined': 100001},
#  'explainVersion': '2',
#  'ok': 1.0,
#  'queryPlanner': {'indexFilterSet': False,
#                   'maxIndexedAndSolutionsReached': False,
#                   'maxIndexedOrSolutionsReached': False,
#                   'maxScansToExplodeReached': False,
#                   'namespace': 'Telegram-090124-crawler.messages',
#                   'parsedQuery': {'fwd_from.from_id.channel_id': {'$not': {'$eq': None}}},
#                   'planCacheKey': '675508F2',
#                   'queryHash': '990113DE',
#                   'rejectedPlans': [],
#                   'winningPlan': {'queryPlan': {'inputStage': {'inputStage': {'direction': 'forward',
#                                                                               'indexBounds': {'fwd_from.from_id.channel_id': ['[MinKey, '
#                                                                                                                               'undefined)',
#                                                                                                                               '(null, '
#                                                                                                                               'MaxKey]']},
#                                                                               'indexName': 'fwd_from.from_id.channel_id_1',
#                                                                               'indexVersion': 2,
#                                                                               'isMultiKey': False,
#                                                                               'isPartial': False,
#                                                                               'isSparse': False,
#                                                                               'isUnique': False,
#                                                                               'keyPattern': {'fwd_from.from_id.channel_id': 1},
#                                                                               'multiKeyPaths': {'fwd_from.from_id.channel_id': []},
#                                                                               'planNodeId': 1,
#                                                                               'stage': 'IXSCAN'},
#                                                                'planNodeId': 2,
#                                                                'stage': 'FETCH'},
#                                                 'limitAmount': 100000,
#                                                 'planNodeId': 3,
#                                                 'stage': 'LIMIT'},
#                                   'slotBasedPlan': {'slots': '$$RESULT=s9 env: '
#                                                              '{ s2 = Nothing '
#                                                              '(SEARCH_META), '
#                                                              's8 = '
#                                                              '{"fwd_from.from_id.channel_id" '
#                                                              ': 1}, s1 = '
#                                                              'TimeZoneDatabase(Etc/GMT-12...America/Cayenne) '
#                                                              '(timeZoneDB), s3 '
#                                                              '= 1706054499855 '
#                                                              '(NOW) }',
#                                                     'stages': '[3] limit '
#                                                               '100000 \n'
#                                                               '[2] nlj inner '
#                                                               '[] [s4, s5, s6, '
#                                                               's7, s8] \n'
#                                                               '    left \n'
#                                                               '        [1] '
#                                                               'ixscan_generic '
#                                                               'IndexBounds("field '
#                                                               "#0['fwd_from.from_id.channel_id']: "
#                                                               '[MinKey, '
#                                                               'undefined), '
#                                                               '(null, '
#                                                               'MaxKey]") s7 s4 '
#                                                               's5 s6 '
#                                                               'lowPriority [] '
#                                                               '@"5f31b076-3332-406c-9a0d-d282667b15a7" '
#                                                               '@"fwd_from.from_id.channel_id_1" '
#                                                               'true \n'
#                                                               '    right \n'
#                                                               '        [2] '
#                                                               'limit 1 \n'
#                                                               '        [2] '
#                                                               'seek s4 s9 s10 '
#                                                               's5 s6 s7 s8 [] '
#                                                               '@"5f31b076-3332-406c-9a0d-d282667b15a7" '
#                                                               'true '
#                                                               'false \n'}}},
#  'serverInfo': {'gitVersion': 'b96efb7e0cf6134d5938de8a94c37cec3f22cff4',
#                 'host': 'cf000588',
#                 'port': 27017,
#                 'version': '7.0.3'},
#  'serverParameters': {'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#                       'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#                       'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#                       'internalQueryFacetBufferSizeBytes': 104857600,
#                       'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#                       'internalQueryFrameworkControl': 'trySbeEngine',
#                       'internalQueryMaxAddToSetBytes': 104857600,
#                       'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#                       'internalQueryProhibitBlockingMergeOnMongoS': 0}}

# %%
explain2 = (
    messages_collection.find(
        {"fwd_from.from_id.channel_id": {"$ne": None}},
        {"message": 1, "fwd_from.from_id.channel_id": 1},
    )
    .limit(100000)
    .explain()
)

pprint(explain2, indent=1)
# Out:
# {'command': {'$db': 'Telegram-090124-crawler',
#              'filter': {'fwd_from.from_id.channel_id': {'$ne': None}},
#              'find': 'messages',
#              'limit': 100000,
#              'projection': {'fwd_from.from_id.channel_id': 1, 'message': 1},
#              'singleBatch': True},
#  'executionStats': {'allPlansExecution': [],
#                     'executionStages': {'closes': 1,
#                                         'executionTimeMillisEstimate': 408,
#                                         'inputStage': {'closes': 1,
#                                                        'executionTimeMillisEstimate': 406,
#                                                        'inputStage': {'closes': 1,
#                                                                       'collectionScans': 0,
#                                                                       'collectionSeeks': 100000,
#                                                                       'executionTimeMillisEstimate': 377,
#                                                                       'indexScans': 0,
#                                                                       'indexSeeks': 1,
#                                                                       'indexesUsed': ['fwd_from.from_id.channel_id_1'],
#                                                                       'innerCloses': 1,
#                                                                       'innerOpens': 100000,
#                                                                       'innerStage': {'closes': 1,
#                                                                                      'executionTimeMillisEstimate': 70,
#                                                                                      'inputStage': {'closes': 1,
#                                                                                                     'executionTimeMillisEstimate': 69,
#                                                                                                     'fields': [],
#                                                                                                     'indexIdentSlot': 6,
#                                                                                                     'indexKeyPatternSlot': 8,
#                                                                                                     'indexKeySlot': 7,
#                                                                                                     'isEOF': 0,
#                                                                                                     'nReturned': 100000,
#                                                                                                     'numReads': 100000,
#                                                                                                     'opens': 100000,
#                                                                                                     'outputSlots': [],
#                                                                                                     'planNodeId': 2,
#                                                                                                     'recordIdSlot': 10,
#                                                                                                     'recordSlot': 9,
#                                                                                                     'restoreState': 100,
#                                                                                                     'saveState': 100,
#                                                                                                     'seekKeySlot': 4,
#                                                                                                     'snapshotIdSlot': 5,
#                                                                                                     'stage': 'seek'},
#                                                                                      'isEOF': 1,
#                                                                                      'limit': 1,
#                                                                                      'nReturned': 100000,
#                                                                                      'opens': 100000,
#                                                                                      'planNodeId': 2,
#                                                                                      'restoreState': 100,
#                                                                                      'saveState': 100,
#                                                                                      'stage': 'limit'},
#                                                                       'isEOF': 0,
#                                                                       'nReturned': 100000,
#                                                                       'opens': 1,
#                                                                       'outerCorrelated': [4,
#                                                                                           5,
#                                                                                           6,
#                                                                                           7,
#                                                                                           8],
#                                                                       'outerProjects': [],
#                                                                       'outerStage': {'closes': 1,
#                                                                                      'executionTimeMillisEstimate': 299,
#                                                                                      'indexIdentSlot': 6,
#                                                                                      'indexKeySlot': 7,
#                                                                                      'indexKeysToInclude': '00000000000000000000000000000000',
#                                                                                      'indexName': 'fwd_from.from_id.channel_id_1',
#                                                                                      'isEOF': 0,
#                                                                                      'keysExamined': 100001,
#                                                                                      'nReturned': 100000,
#                                                                                      'numReads': 100001,
#                                                                                      'opens': 1,
#                                                                                      'outputSlots': [],
#                                                                                      'planNodeId': 1,
#                                                                                      'recordIdSlot': 4,
#                                                                                      'restoreState': 100,
#                                                                                      'saveState': 100,
#                                                                                      'seeks': 2,
#                                                                                      'snapshotIdSlot': 5,
#                                                                                      'stage': 'ixscan_generic'},
#                                                                       'planNodeId': 2,
#                                                                       'restoreState': 100,
#                                                                       'saveState': 100,
#                                                                       'stage': 'nlj',
#                                                                       'totalDocsExamined': 100000,
#                                                                       'totalKeysExamined': 100001},
#                                                        'isEOF': 0,
#                                                        'nReturned': 100000,
#                                                        'opens': 1,
#                                                        'planNodeId': 3,
#                                                        'projections': {'11': 'traverseP(s9, '
#                                                                              'lambda(l1.0) '
#                                                                              '{ \n'
#                                                                              '    '
#                                                                              'if '
#                                                                              'isObject(l1.0) \n'
#                                                                              '    '
#                                                                              'then '
#                                                                              'makeBsonObj(MakeObjSpec(keep, '
#                                                                              '["message", '
#                                                                              '"_id"], '
#                                                                              '["fwd_from"]), '
#                                                                              'l1.0, '
#                                                                              'traverseP(getField(l1.0, '
#                                                                              '"fwd_from"), '
#                                                                              'lambda(l2.0) '
#                                                                              '{ \n'
#                                                                              '        '
#                                                                              'if '
#                                                                              'isObject(l2.0) \n'
#                                                                              '        '
#                                                                              'then '
#                                                                              'makeBsonObj(MakeObjSpec(keep, '
#                                                                              '[], '
#                                                                              '["from_id"]), '
#                                                                              'l2.0, '
#                                                                              'traverseP(getField(l2.0, '
#                                                                              '"from_id"), '
#                                                                              'lambda(l3.0) '
#                                                                              '{ \n'
#                                                                              '            '
#                                                                              'if '
#                                                                              'isObject(l3.0) \n'
#                                                                              '            '
#                                                                              'then '
#                                                                              'makeBsonObj(MakeObjSpec(keep, '
#                                                                              '["channel_id"], '
#                                                                              '[]), '
#                                                                              'l3.0) \n'
#                                                                              '            '
#                                                                              'else '
#                                                                              'Nothing \n'
#                                                                              '        '
#                                                                              '}, '
#                                                                              'Nothing)) \n'
#                                                                              '        '
#                                                                              'else '
#                                                                              'Nothing \n'
#                                                                              '    '
#                                                                              '}, '
#                                                                              'Nothing)) \n'
#                                                                              '    '
#                                                                              'else '
#                                                                              'Nothing \n'
#                                                                              '}, '
#                                                                              'Nothing) '},
#                                                        'restoreState': 100,
#                                                        'saveState': 100,
#                                                        'stage': 'project'},
#                                         'isEOF': 1,
#                                         'limit': 100000,
#                                         'nReturned': 100000,
#                                         'opens': 1,
#                                         'planNodeId': 4,
#                                         'restoreState': 100,
#                                         'saveState': 100,
#                                         'stage': 'limit'},
#                     'executionSuccess': True,
#                     'executionTimeMillis': 417,
#                     'nReturned': 100000,
#                     'totalDocsExamined': 100000,
#                     'totalKeysExamined': 100001},
#  'explainVersion': '2',
#  'ok': 1.0,
#  'queryPlanner': {'indexFilterSet': False,
#                   'maxIndexedAndSolutionsReached': False,
#                   'maxIndexedOrSolutionsReached': False,
#                   'maxScansToExplodeReached': False,
#                   'namespace': 'Telegram-090124-crawler.messages',
#                   'parsedQuery': {'fwd_from.from_id.channel_id': {'$not': {'$eq': None}}},
#                   'planCacheKey': '21D1E058',
#                   'queryHash': '0732E017',
#                   'rejectedPlans': [],
#                   'winningPlan': {'queryPlan': {'inputStage': {'inputStage': {'inputStage': {'direction': 'forward',
#                                                                                              'indexBounds': {'fwd_from.from_id.channel_id': ['[MinKey, '
#                                                                                                                                              'undefined)',
#                                                                                                                                              '(null, '
#                                                                                                                                              'MaxKey]']},
#                                                                                              'indexName': 'fwd_from.from_id.channel_id_1',
#                                                                                              'indexVersion': 2,
#                                                                                              'isMultiKey': False,
#                                                                                              'isPartial': False,
#                                                                                              'isSparse': False,
#                                                                                              'isUnique': False,
#                                                                                              'keyPattern': {'fwd_from.from_id.channel_id': 1},
#                                                                                              'multiKeyPaths': {'fwd_from.from_id.channel_id': []},
#                                                                                              'planNodeId': 1,
#                                                                                              'stage': 'IXSCAN'},
#                                                                               'planNodeId': 2,
#                                                                               'stage': 'FETCH'},
#                                                                'planNodeId': 3,
#                                                                'stage': 'PROJECTION_DEFAULT',
#                                                                'transformBy': {'_id': True,
#                                                                                'fwd_from': {'from_id': {'channel_id': True}},
#                                                                                'message': True}},
#                                                 'limitAmount': 100000,
#                                                 'planNodeId': 4,
#                                                 'stage': 'LIMIT'},
#                                   'slotBasedPlan': {'slots': '$$RESULT=s11 '
#                                                              'env: { s1 = '
#                                                              'TimeZoneDatabase(Etc/GMT-12...America/Cayenne) '
#                                                              '(timeZoneDB), s2 '
#                                                              '= Nothing '
#                                                              '(SEARCH_META), '
#                                                              's8 = '
#                                                              '{"fwd_from.from_id.channel_id" '
#                                                              ': 1}, s3 = '
#                                                              '1706054612618 '
#                                                              '(NOW) }',
#                                                     'stages': '[4] limit '
#                                                               '100000 \n'
#                                                               '[3] project '
#                                                               '[s11 = '
#                                                               'traverseP(s9, '
#                                                               'lambda(l1.0) '
#                                                               '{ \n'
#                                                               '    if '
#                                                               'isObject(l1.0) \n'
#                                                               '    then '
#                                                               'makeBsonObj(MakeObjSpec(keep, '
#                                                               '["message", '
#                                                               '"_id"], '
#                                                               '["fwd_from"]), '
#                                                               'l1.0, '
#                                                               'traverseP(getField(l1.0, '
#                                                               '"fwd_from"), '
#                                                               'lambda(l2.0) '
#                                                               '{ \n'
#                                                               '        if '
#                                                               'isObject(l2.0) \n'
#                                                               '        then '
#                                                               'makeBsonObj(MakeObjSpec(keep, '
#                                                               '[], '
#                                                               '["from_id"]), '
#                                                               'l2.0, '
#                                                               'traverseP(getField(l2.0, '
#                                                               '"from_id"), '
#                                                               'lambda(l3.0) '
#                                                               '{ \n'
#                                                               '            if '
#                                                               'isObject(l3.0) \n'
#                                                               '            '
#                                                               'then '
#                                                               'makeBsonObj(MakeObjSpec(keep, '
#                                                               '["channel_id"], '
#                                                               '[]), l3.0) \n'
#                                                               '            '
#                                                               'else Nothing \n'
#                                                               '        }, '
#                                                               'Nothing)) \n'
#                                                               '        else '
#                                                               'Nothing \n'
#                                                               '    }, '
#                                                               'Nothing)) \n'
#                                                               '    else '
#                                                               'Nothing \n'
#                                                               '}, Nothing)] \n'
#                                                               '[2] nlj inner '
#                                                               '[] [s4, s5, s6, '
#                                                               's7, s8] \n'
#                                                               '    left \n'
#                                                               '        [1] '
#                                                               'ixscan_generic '
#                                                               'IndexBounds("field '
#                                                               "#0['fwd_from.from_id.channel_id']: "
#                                                               '[MinKey, '
#                                                               'undefined), '
#                                                               '(null, '
#                                                               'MaxKey]") s7 s4 '
#                                                               's5 s6 '
#                                                               'lowPriority [] '
#                                                               '@"5f31b076-3332-406c-9a0d-d282667b15a7" '
#                                                               '@"fwd_from.from_id.channel_id_1" '
#                                                               'true \n'
#                                                               '    right \n'
#                                                               '        [2] '
#                                                               'limit 1 \n'
#                                                               '        [2] '
#                                                               'seek s4 s9 s10 '
#                                                               's5 s6 s7 s8 [] '
#                                                               '@"5f31b076-3332-406c-9a0d-d282667b15a7" '
#                                                               'true '
#                                                               'false \n'}}},
#  'serverInfo': {'gitVersion': 'b96efb7e0cf6134d5938de8a94c37cec3f22cff4',
#                 'host': 'cf000588',
#                 'port': 27017,
#                 'version': '7.0.3'},
#  'serverParameters': {'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#                       'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#                       'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#                       'internalQueryFacetBufferSizeBytes': 104857600,
#                       'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#                       'internalQueryFrameworkControl': 'trySbeEngine',
#                       'internalQueryMaxAddToSetBytes': 104857600,
#                       'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#                       'internalQueryProhibitBlockingMergeOnMongoS': 0}}
